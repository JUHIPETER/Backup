# %%
import pandas as pd
import os
os.getcwd()
os.chdir(r"C:\\Users\\Merit\\Desktop\\Project\\Task_KT")
NameData=pd.read_excel("Python_ex.xlsx")
#Storing in DataFrame
DF_Name= pd.DataFrame(NameData)
DF_Name
# Out:
#    Drug Name Traffic Light    Indication   Status
# 0     Drug A          Red   Indication 1      NaN
# 1     Drug A         Amber  Indication 2  Updated
# 2     Drug B         Green  Indication 3  Updated
# 3     Drug C         Green  Indication 4  Updated
# 4     Drug C         Amber  Indication 5      NaN
# ..       ...           ...           ...      ...
# 67    Drug L         Green  Indication 2  Updated
# 68    Drug L         Amber  Indication 2  Updated
# 69    Drug L          Red   Indication 2  Updated
# 70    Drug L         Green  Indication 2  Updated
# 71    Drug J         Amber  Indication 2  Updated
#
# [72 rows x 4 columns]

# %%
lst=[]
for i in DF_Name.index:
    lst.append(DF_Name['Drug Name'][i])
    
st=set(lst)
st
# Out:
# {'Drug A',
#  'Drug B',
#  'Drug C',
#  'Drug D',
#  'Drug E',
#  'Drug F',
#  'Drug I',
#  'Drug J',
#  'Drug K',
#  'Drug L'}

# %%
for i in st:
    flag=1
    for j in DF_Name.index:
        if(i==DF_Name['Drug Name'][j]):
            if(DF_Name["Status"].isnull()[j]):
                flag=0
        
    if(flag):
        print(i+" updated and other row item from "+ i + " has correctly marked as updated")
    else:
        print(i+" is updated but other row item from "+ i + " has not marked as Updated")
# Out:
# Drug A is updated but other row item from Drug A has not marked as Updated
# Drug K is updated but other row item from Drug K has not marked as Updated
# Drug E is updated but other row item from Drug E has not marked as Updated
# Drug B is updated but other row item from Drug B has not marked as Updated
# Drug F updated and other row item from Drug F has correctly marked as updated
# Drug C is updated but other row item from Drug C has not marked as Updated
# Drug I updated and other row item from Drug I has correctly marked as updated
# Drug D updated and other row item from Drug D has correctly marked as updated
# Drug L is updated but other row item from Drug L has not marked as Updated
# Drug J updated and other row item from Drug J has correctly marked as updated

# %%
# %%time
import pandas as pd
import os
os.getcwd()
os.chdir(r"C:\\Users\\Merit\\Desktop\\Project\\Task_KT")
NameData=pd.read_excel("Python_ex.xlsx")
#Storing in DataFrame
DF_Name= pd.DataFrame(NameData)
# DF_Name

lst=[]
for i in DF_Name.index:
    lst.append(DF_Name['Drug Name'][i])
    
st=set(lst)
# st

for i in st:
    flag=1
    for j in DF_Name.index:
        if(i==DF_Name['Drug Name'][j]):
            if(DF_Name["Status"].isnull()[j]):
                flag=0
        
    if(flag):
        print(i+" updated and other row item from "+ i + " has correctly marked as updated")
    else:
        print(i+" is updated but other row item from "+ i + " has not marked as Updated")
# Out:
# Drug I updated and other row item from Drug I has correctly marked as updated
# Drug C is updated but other row item from Drug C has not marked as Updated
# Drug L is updated but other row item from Drug L has not marked as Updated
# Drug J updated and other row item from Drug J has correctly marked as updated
# Drug A is updated but other row item from Drug A has not marked as Updated
# Drug F updated and other row item from Drug F has correctly marked as updated
# Drug K is updated but other row item from Drug K has not marked as Updated
# Drug D updated and other row item from Drug D has correctly marked as updated
# Drug E is updated but other row item from Drug E has not marked as Updated
# Drug B is updated but other row item from Drug B has not marked as Updated
# Wall time: 1.45 s
