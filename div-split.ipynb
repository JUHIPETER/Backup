# %%
import selenium
from selenium import webdriver
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
from selenium.webdriver.support.ui import Select
import time
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
import os
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

driverPath = r"C:\Users\Merit\PycharmProjects\chrome\chromedriver_win32 (1)\chromedriver.exe"
driver = webdriver.Chrome(executable_path = driverPath)
driver.get("https://www.cravath.com/people/index.html")
print(driver.title)
print(driver.current_url)
driver.maximize_window()

driver.find_element_by_xpath("(//*[contains(@class, 'icon-Close styles__closeButton--03a22cd7')])").click()
time.sleep(3)
a = driver.find_elements_by_class_name("l-vgap-generic-interior-section")

for j in range(0,len(a)):
    try:

        if(a[j].find_element_by_class_name("card-lister-cta__viewAllArrow--875950ce")):

            a[j].find_element_by_class_name("card-lister-cta__viewAllArrow--875950ce").click()
            time.sleep(5)
            while (True):
                part = a[j].find_elements_by_class_name("l-content-container")
                AB = a[j].find_elements_by_class_name("card-lister__box--554421f0")
                for i in range(0, len(AB)):
                    # print(len(AB))
                    # print(AB[1].text)
                    per = AB[i].text.split("\n")
                    print(per)
                    name = per[0]
                    practice = per[1]
                    index1 = [i for i, elem in enumerate(per) if '@' in elem]
                    email = per[index1[0]] if len(index1) else "Null"
                    index2 = [i for i, elem in enumerate(per) if '+' in elem]
                    tel = per[index2[0]] if len(index2) else "Null"
                    pos = part[0].text.capitalize()


                    print(name)
                    print(email)
                    print(practice)
                    print(tel)
                    print(pos)
                    print(driver.current_url)
                    print("--------------------------------------------------------------------")
                try:
                    if (driver.find_element_by_xpath(
                            "(//*[contains(@class, 'styles__arrow--fd23c3f5 icon-caret-thin-right hover-color-dodger-blue')])").is_enabled()):
                        driver.find_element_by_xpath(
                            "(//*[contains(@class, 'styles__arrow--fd23c3f5 icon-caret-thin-right hover-color-dodger-blue')])").click()

                        time.sleep(2)
                        print("############################################################################")
                except:

                    driver.find_element_by_xpath('//a[contains(@href,"https://www.cravath.com/people/index.html")]').click()
                    break
            driver.refresh()


    except:
        part = a[j].find_elements_by_class_name("l-content-container")
        AB = a[j].find_elements_by_class_name("card-lister__box--554421f0")
        for i in range(0, len(AB)):
            # print(len(AB))
            # print(AB[1].text)
            per = AB[i].text.split("\n")
            print(per)
            name = per[0]
            practice = per[1]
            index1 = [i for i, elem in enumerate(per) if '@' in elem]
            email = per[index1[0]] if len(index1) else "Null"
            index2 = [i for i, elem in enumerate(per) if '+' in elem]
            tel = per[index2[0]] if len(index2) else "Null"
            pos = part[0].text.capitalize()

            print(name)
            print(email)
            print(practice)
            print(tel)
            print(pos)
            print(driver.current_url)
            print("----------------------------------------------------------------------------------")
    print("************************")
    a = driver.find_elements_by_class_name("l-vgap-generic-interior-section")
# Out:
# People | Cravath, Swaine & Moore LLP
# https://www.cravath.com/people/index.html
# ['Michael P. Addis', 'LITIGATION', 'Partner', 'maddis@cravath.com', '+1-212-474-1956', 'Download vCard', 'EDUCATION', 'J.D., 2010, Harvard Law School', 'M.S.T., 2007, Pace University', 'A.B., 2005, Princeton University', 'magna cum laude', 'CLERKSHIPS', 'Hon. Kermit V. Lipez, U.S. Court of Appeals for the First Circuit', 'ADMITTED ONLY IN', 'New York']
# Michael P. Addis
# maddis@cravath.com
# LITIGATION
# +1-212-474-1956
# Partner
# https://www.cravath.com/people/index.html?po=5499&s=20
# --------------------------------------------------------------------
# ['Lauren Angelilli', 'TAX', 'Partner', 'langelilli@cravath.com', '+1-212-474-1016', 'Download vCard', 'EDUCATION', 'J.D., 2000, Harvard Law School', 'cum laude', 'B.S., 1996, The Wharton School, University of Pennsylvania', 'magna cum laude', 'ADMITTED ONLY IN', 'New York']
# Lauren Angelilli
# langelilli@cravath.com
# TAX
# +1-212-474-1016
# Partner
# https://www.cravath.com/people/index.html?po=5499&s=20
# --------------------------------------------------------------------
# ['Craig F. Arcella', 'CORPORATE', 'Partner', 'carcella@cravath.com', '+1-212-474-1024', 'Download vCard', 'EDUCATION', 'J.D., 1998, Columbia Law School', 'Harlan Fiske Stone Scholar', 'B.A., 1995, Duke University', 'ADMITTED ONLY IN', 'New York']
# Craig F. Arcella
# carcella@cravath.com
# CORPORATE
# +1-212-474-1024
# Partner
# https://www.cravath.com/people/index.html?po=5499&s=20
# --------------------------------------------------------------------
# ['Michael L. Arnold', 'CORPORATE', 'Partner', 'marnold@cravath.com', '+1-212-474-1664', 'Download vCard', 'EDUCATION', 'J.D., 2013, Columbia Law School', 'Harlan Fiske Stone Scholar', 'B.A., 2010, University of Chicago', 'ADMITTED ONLY IN', 'New York']
# Michael L. Arnold
# marnold@cravath.com
# CORPORATE
# +1-212-474-1664
# Partner
# https://www.cravath.com/people/index.html?po=5499&s=20
# --------------------------------------------------------------------
# ['Peter T. Barbur', 'LITIGATION', 'Partner', 'pbarbur@cravath.com', '+1-212-474-1058', 'Download vCard', 'EDUCATION', 'J.D., 1987, New York University School of Law', 'Order of the Coif, Root-Tilden Scholar, cum laude', 'B.A., 1983, Dartmouth College', 'Phi Beta Kappa, magna cum laude', 'CLERKSHIPS', 'Hon. Hugh H. Bownes, U.S. Court of Appeals for the First Circuit', 'ADMITTED ONLY IN', 'New York']
# Peter T. Barbur
# pbarbur@cravath.com
# LITIGATION
# +1-212-474-1058
# Partner
# https://www.cravath.com/people/index.html?po=5499&s=20
# --------------------------------------------------------------------
# ['Robert H. Baron', 'LITIGATION', 'Partner', 'rbaron@cravath.com', '+1-212-474-1422', 'Download vCard', 'EDUCATION', 'J.D., 1981, Harvard Law School', 'cum laude', 'A.B., 1978, Princeton University', 'cum laude', 'ADMITTED ONLY IN', 'New York']
# Robert H. Baron
# rbaron@cravath.com
# LITIGATION
# +1-212-474-1422
# Partner
# https://www.cravath.com/people/index.html?po=5499&s=20
# --------------------------------------------------------------------
# ['Heather A. Benjamin', 'TRUSTS AND ESTATES', 'Partner', 'hbenjamin@cravath.com', '+1-212-474-1144', 'Download vCard', 'EDUCATION', 'J.D., 2010, Harvard Law School', 'B.A., 2005, New York University', 'ADMITTED ONLY IN', 'New York']
# Heather A. Benjamin
# hbenjamin@cravath.com
# TRUSTS AND ESTATES
# +1-212-474-1144
# Partner
# https://www.cravath.com/people/index.html?po=5499&s=20
# --------------------------------------------------------------------
# ['D. Scott Bennett', 'CORPORATE', 'Partner', 'sbennett@cravath.com', '+1-212-474-1132', 'Download vCard', 'EDUCATION', 'J.D., 2006, Emory University Law School', 'Order of the Coif; James Colson Scholar', 'B.A., 2002, Duke University', 'ADMITTED ONLY IN', 'New York']
# D. Scott Bennett
# sbennett@cravath.com
# CORPORATE
# +1-212-474-1132
# Partner
# https://www.cravath.com/people/index.html?po=5499&s=20
# --------------------------------------------------------------------
# ['Matthew J. Bobby', 'EXECUTIVE COMPENSATION AND BENEFITS', 'Partner', 'mbobby@cravath.com', '+1-212-474-1128', 'Download vCard', 'EDUCATION', 'J.D., 2012, Harvard Law School', 'magna cum laude', 'M.A., 2009, University of Pennsylvania', 'B.A., 2009, University of Pennsylvania', 'Phi Beta Kappa, summa cum laude', 'CLERKSHIPS', 'Hon. Jerome Farris, U.S. Court of Appeals for the Ninth Circuit', 'ADMITTED ONLY IN', 'New York']
# Matthew J. Bobby
# mbobby@cravath.com
# EXECUTIVE COMPENSATION AND BENEFITS
# +1-212-474-1128
# Partner
# https://www.cravath.com/people/index.html?po=5499&s=20
# --------------------------------------------------------------------
# ['Philip J. Boeckman', 'CORPORATE', 'Partner', 'pboeckman@cravath.com', '+44-20-7453-1020', 'Download vCard', 'EDUCATION', 'J.D., 1991, University of Missouri Columbia School of Law', 'Order of the Coif, magna cum laude', 'B.A., 1988, Westminster College', 'cum laude', 'ADMITTED ONLY IN', 'New York']
# Philip J. Boeckman
# pboeckman@cravath.com
# CORPORATE
# +44-20-7453-1020
# Partner
# https://www.cravath.com/people/index.html?po=5499&s=20
# --------------------------------------------------------------------
# ['Gary A. Bornstein', 'LITIGATION', 'Partner', 'gbornstein@cravath.com', '+1-212-474-1084', 'Download vCard', 'EDUCATION', 'J.D., 1997, Harvard Law School', 'magna cum laude', 'B.A., 1994, Yale College', 'Phi Beta Kappa, magna cum laude', 'CLERKSHIPS', 'Hon. Amalya L. Kearse, U.S. Court of Appeals for the Second Circuit', 'ADMITTED ONLY IN', 'New York']
# Gary A. Bornstein
# gbornstein@cravath.com
# LITIGATION
# +1-212-474-1084
# Partner
# https://www.cravath.com/people/index.html?po=5499&s=20
# --------------------------------------------------------------------
# ['John D. Buretta', 'LITIGATION', 'Partner', 'jburetta@cravath.com', '+1-212-474-1260', 'Download vCard', 'EDUCATION', 'J.D., 1996, Georgetown University Law Center', 'cum laude', 'B.A., 1993, University of California, Berkeley', 'CLERKSHIPS', 'Hon. Peter K. Leisure, U.S.D.C. for the Southern District of New York', 'ADMITTED ONLY IN', 'New York']
# John D. Buretta
# jburetta@cravath.com
# LITIGATION
# +1-212-474-1260
# Partner
# https://www.cravath.com/people/index.html?po=5499&s=20
# --------------------------------------------------------------------
# ['Stephen L. Burns', 'CORPORATE', 'Partner', 'sburns@cravath.com', '+1-212-474-1146', 'Download vCard', 'EDUCATION', 'J.D., 1990, The University of Texas School of Law', 'with Honors', 'B.B.A., 1987, University of Oklahoma', 'with Distinction', 'ADMITTED ONLY IN', 'New York']
# Stephen L. Burns
# sburns@cravath.com
# CORPORATE
# +1-212-474-1146
# Partner
# https://www.cravath.com/people/index.html?po=5499&s=20
# --------------------------------------------------------------------
# ['Timothy G. Cameron', 'LITIGATION', 'Partner', 'tcameron@cravath.com', '+1-212-474-1120', 'Download vCard', 'EDUCATION', 'LL.M., 1998, University of Chicago Law School', 'M.ComLaw, 1997, Auckland University - Faculty of Law', 'First Class Honors', 'LL.B., 1994, Auckland University - Faculty of Law', 'B.Com., 1994, Auckland University - Faculty of Law', 'ADMITTED ONLY IN', 'New York']
# Timothy G. Cameron
# tcameron@cravath.com
# LITIGATION
# +1-212-474-1120
# Partner
# https://www.cravath.com/people/index.html?po=5499&s=20
# --------------------------------------------------------------------
# ['Alyssa K. Caples', 'CORPORATE', 'Partner', 'acaples@cravath.com', '+44-20-7453-1090', 'Download vCard', 'EDUCATION', 'J.D., 2000, Harvard Law School', 'cum laude', 'B.A., 1997, Columbia University', 'Phi Beta Kappa, summa cum laude', 'ADMITTED ONLY IN', 'New York']
# Alyssa K. Caples
# acaples@cravath.com
# CORPORATE
# +44-20-7453-1090
# Partner
# https://www.cravath.com/people/index.html?po=5499&s=20
# --------------------------------------------------------------------
# ['Daniel J. Cerqueira', 'CORPORATE', 'Partner', 'dcerqueira@cravath.com', '+1-212-474-1156', 'Download vCard', 'EDUCATION', 'J.D., 2013, Harvard Law School', 'magna cum laude', 'B.A., 2010, Cornell University', 'Phi Beta Kappa', 'ADMITTED ONLY IN', 'New York']
# Daniel J. Cerqueira
# dcerqueira@cravath.com
# CORPORATE
# +1-212-474-1156
# Partner
# https://www.cravath.com/people/index.html?po=5499&s=20
# --------------------------------------------------------------------
# ['Ting S. Chen', 'CORPORATE', 'Partner', 'tchen@cravath.com', '+1-212-474-1794', 'Download vCard', 'EDUCATION', 'J.D., 2006, Stanford Law School', 'A.B., 2003, Harvard College', 'Phi Beta Kappa, summa cum laude', 'ADMITTED ONLY IN', 'New York']
# Ting S. Chen
# tchen@cravath.com
# CORPORATE
# +1-212-474-1794
# Partner
# https://www.cravath.com/people/index.html?po=5499&s=20
# --------------------------------------------------------------------
# ['Evan R. Chesler', 'LITIGATION', 'Partner', 'echesler@cravath.com', '+1-212-474-1243', 'Download vCard', 'EDUCATION', 'J.D., 1975, New York University School of Law', 'Order of the Coif, John Norton Pomeroy Scholar, cum laude', 'M.A., 1973, Hunter College', 'summa cum laude', 'A.B., 1970, New York University', 'CLERKSHIPS', 'Hon. Inzer B. Wyatt, U.S.D.C. for the Southern District of New York', 'ADMITTED ONLY IN', 'New York']
# Evan R. Chesler
# echesler@cravath.com
# LITIGATION
# +1-212-474-1243
# Partner
# https://www.cravath.com/people/index.html?po=5499&s=20
# --------------------------------------------------------------------
# ['Justin C. Clarke', 'LITIGATION', 'Partner', 'jcclarke@cravath.com', '+1-212-474-1184', 'Download vCard', 'EDUCATION', 'J.D., 2011, Columbia Law School', 'Stone Scholar; Kent Scholar', 'A.B., 2004, Bowdoin College', 'CLERKSHIPS', 'Hon. Amalya L. Kearse, U.S. Court of Appeals for the Second Circuit', 'ADMITTED ONLY IN', 'New York']
# Justin C. Clarke
# jcclarke@cravath.com
# LITIGATION
# +1-212-474-1184
# Partner
# https://www.cravath.com/people/index.html?po=5499&s=20
# --------------------------------------------------------------------
# ['Jennifer S. Conway', 'EXECUTIVE COMPENSATION AND BENEFITS', 'Partner', 'jconway@cravath.com', '+1-212-474-1316', 'Download vCard', 'EDUCATION', 'J.D., 2001, Columbia Law School', 'James Kent Scholar', 'B.S.F.S., 1996, Georgetown University', 'cum laude', 'ADMITTED ONLY IN', 'New York']
# Jennifer S. Conway
# jconway@cravath.com
# EXECUTIVE COMPENSATION AND BENEFITS
# +1-212-474-1316
# Partner
# https://www.cravath.com/people/index.html?po=5499&s=20
# --------------------------------------------------------------------
# ############################################################################
# ['Ronald E. Creamer Jr.', 'TAX', 'Partner', 'rcreamer@cravath.com', '+1-212-474-1010', 'Download vCard', 'EDUCATION', 'M.P.P.M., 1991, Yale University', 'J.D., 1991, Yale Law School', 'A.B., 1987, Princeton University', 'ADMITTED ONLY IN', 'New York']
# Ronald E. Creamer Jr.
# rcreamer@cravath.com
# TAX
# +1-212-474-1010
# Partner
# https://www.cravath.com/people/index.html?f=20&po=5499&s=20
# --------------------------------------------------------------------
# ['Karin A. DeMasi', 'LITIGATION', 'Partner', 'kdemasi@cravath.com', '+1-212-474-1059', 'Download vCard', 'EDUCATION', 'J.D., 1996, University of Pennsylvania Law School', 'B.S., 1993, Northwestern University', 'CLERKSHIPS', 'Hon. D. Brock Hornby, U.S.D.C. for the District of Maine', 'ADMITTED ONLY IN', 'New York']
# Karin A. DeMasi
# kdemasi@cravath.com
# LITIGATION
# +1-212-474-1059
# Partner
# https://www.cravath.com/people/index.html?f=20&po=5499&s=20
# --------------------------------------------------------------------
# ['Alexandra C. Denning', 'TRUSTS AND ESTATES', 'Partner', 'adenning@cravath.com', '+1-212-474-1574', 'Download vCard', 'EDUCATION', 'LL.M., 2017, New York University School of Law', 'J.D., 2010, Yale Law School', 'B.A., 2004, Williams College', 'Phi Beta Kappa, magna cum laude', 'CLERKSHIPS', 'Hon. Michael J. Melloy, U.S. Court of Appeals for the Eighth Circuit', 'ADMITTED ONLY IN', 'New York']
# Alexandra C. Denning
# adenning@cravath.com
# TRUSTS AND ESTATES
# +1-212-474-1574
# Partner
# https://www.cravath.com/people/index.html?f=20&po=5499&s=20
# --------------------------------------------------------------------
# ['Nicholas A. Dorsey', 'CORPORATE', 'Partner', 'ndorsey@cravath.com', '+1-212-474-1764', 'Download vCard', 'EDUCATION', 'J.D., 2009, Cornell Law School', 'Order of the Coif, summa cum laude', 'M.Acc., 2006, Case Western Reserve University', 'summa cum laude', 'B.S., 2006, Case Western Reserve University', 'summa cum laude', 'ADMITTED ONLY IN', 'New York']
# Nicholas A. Dorsey
# ndorsey@cravath.com
# CORPORATE
# +1-212-474-1764
# Partner
# https://www.cravath.com/people/index.html?f=20&po=5499&s=20
# --------------------------------------------------------------------
# ['Thomas E. Dunn', 'CORPORATE', 'Partner', 'tdunn@cravath.com', '+1-212-474-1108', 'Download vCard', 'EDUCATION', 'J.D., 1992, Duke Law School', 'summa cum laude', 'B.A., 1987, The College of William & Mary', 'ADMITTED ONLY IN', 'New York']
# Thomas E. Dunn
# tdunn@cravath.com
# CORPORATE
# +1-212-474-1108
# Partner
# https://www.cravath.com/people/index.html?f=20&po=5499&s=20
# --------------------------------------------------------------------
# ['Wes Earnhardt', 'LITIGATION', 'Partner', 'wearnhardt@cravath.com', '+1-212-474-1138', 'Download vCard', 'EDUCATION', 'J.D., 2004, University of North Carolina School of Law', 'B.A., 2000, University of North Carolina at Chapel Hill', 'Phi Beta Kappa', 'ADMITTED ONLY IN', 'New York']
# Wes Earnhardt
# wearnhardt@cravath.com
# LITIGATION
# +1-212-474-1138
# Partner
# https://www.cravath.com/people/index.html?f=20&po=5499&s=20
# --------------------------------------------------------------------
# ['Andrew C. Elken', 'CORPORATE', 'Partner', 'aelken@cravath.com', '+1-212-474-1414', 'Download vCard', 'EDUCATION', 'J.D., 2009, University of Southern California School of Law', 'Order of the Coif', 'A.B., 2004, Princeton University', 'ADMITTED ONLY IN', 'New York']
# Andrew C. Elken
# aelken@cravath.com
# CORPORATE
# +1-212-474-1414
# Partner
# https://www.cravath.com/people/index.html?f=20&po=5499&s=20
# --------------------------------------------------------------------
# ['Yonatan Even', 'LITIGATION', 'Partner', 'yeven@cravath.com', '+1-212-474-1958', 'Download vCard', 'EDUCATION', 'J.S.D., 2009, Columbia Law School', 'LL.M., 2004, Columbia Law School', 'James Kent Scholar', 'LL.B., 1999, Tel Aviv University', 'magna cum laude', 'ADMITTED ONLY IN', 'New York']
# Yonatan Even
# yeven@cravath.com
# LITIGATION
# +1-212-474-1958
# Partner
# https://www.cravath.com/people/index.html?f=20&po=5499&s=20
# --------------------------------------------------------------------
# ['Christopher K. Fargo', 'TAX', 'Partner', 'cfargo@cravath.com', '+1-212-474-1236', 'Download vCard', 'EDUCATION', 'J.D., 2006, Columbia Law School', 'Harlan Fiske Stone; Michael Lynne Scholar', 'B.A., 2003, Boston College', 'Honors Program, cum laude', 'ADMITTED ONLY IN', 'New York']
# Christopher K. Fargo
# cfargo@cravath.com
# TAX
# +1-212-474-1236
# Partner
# https://www.cravath.com/people/index.html?f=20&po=5499&s=20
# --------------------------------------------------------------------
# ['David S. Finkelstein', 'TRUSTS AND ESTATES', 'Partner', 'dfinkelstein@cravath.com', '+1-212-474-1304', 'Download vCard', 'EDUCATION', 'LL.M., 2000, New York University', 'J.D., 1998, Fordham University School of Law', 'magna cum laude', 'B.A., 1994, Harvard College', 'cum laude', 'ADMITTED ONLY IN', 'New York']
# David S. Finkelstein
# dfinkelstein@cravath.com
# TRUSTS AND ESTATES
# +1-212-474-1304
# Partner
# https://www.cravath.com/people/index.html?f=20&po=5499&s=20
# --------------------------------------------------------------------
# ['William V. Fogg', 'CORPORATE', 'Partner', 'wfogg@cravath.com', '+1-212-474-1131', 'Download vCard', 'EDUCATION', 'J.D., 1991, Columbia Law School', 'Harlan Fiske Stone Scholar', 'A.B., 1988, Brown University', 'magna cum laude', 'ADMITTED ONLY IN', 'New York']
# William V. Fogg
# wfogg@cravath.com
# CORPORATE
# +1-212-474-1131
# Partner
# https://www.cravath.com/people/index.html?f=20&po=5499&s=20
# --------------------------------------------------------------------
# ['Hon. Katherine B. Forrest (fmr.)', 'LITIGATION', 'Partner', 'kforrest@cravath.com', '+1-212-474-1151', 'Download vCard', 'EDUCATION', 'J.D., 1990, New York University School of Law', 'B.A., 1986, Wesleyan University', 'with Honors', 'ADMITTED ONLY IN', 'New York']
# Hon. Katherine B. Forrest (fmr.)
# kforrest@cravath.com
# LITIGATION
# +1-212-474-1151
# Partner
# https://www.cravath.com/people/index.html?f=20&po=5499&s=20
# --------------------------------------------------------------------
# ['Helam Gebremariam', 'LITIGATION', 'Partner', 'hgebremariam@cravath.com', '+1-212-474-1180', 'Download vCard', 'EDUCATION', 'J.D., 2010, New York University School of Law', 'AnBryce Scholar', 'B.A., 2007, Columbia College', 'CLERKSHIPS', 'Hon. Robert P. Patterson, U.S.D.C. for the Southern District of New York', 'ADMITTED ONLY IN', 'New York']
# Helam Gebremariam
# hgebremariam@cravath.com
# LITIGATION
# +1-212-474-1180
# Partner
# https://www.cravath.com/people/index.html?f=20&po=5499&s=20
# --------------------------------------------------------------------
# ['Michael S. Goldman', 'CORPORATE', 'Partner', 'mgoldman@cravath.com', '+1-212-474-1929', 'Download vCard', 'EDUCATION', 'J.D., 1987, Fordham University School of Law', 'cum laude', 'B.A., 1984, University of Pennsylvania', 'cum laude', 'ADMITTED ONLY IN', 'New York']
# Michael S. Goldman
# mgoldman@cravath.com
# CORPORATE
# +1-212-474-1929
# Partner
# https://www.cravath.com/people/index.html?f=20&po=5499&s=20
# --------------------------------------------------------------------
# ['Stephen L. Gordon', 'TAX', 'Partner', 'gordon@cravath.com', '+1-212-474-1704', 'Download vCard', 'EDUCATION', 'J.D., 1981, Harvard Law School', 'cum laude', 'A.B., 1978, Cornell University', 'cum laude', 'ADMITTED ONLY IN', 'New York']
# Stephen L. Gordon
# gordon@cravath.com
# TAX
# +1-212-474-1704
# Partner
# https://www.cravath.com/people/index.html?f=20&po=5499&s=20
# --------------------------------------------------------------------
# ['Sharonmoyee Goswami', 'LITIGATION', 'Partner', 'sgoswami@cravath.com', '+1-212-474-1928', 'Download vCard', 'EDUCATION', 'J.D., 2012, New York University School of Law', 'Order of the Coif., magna cum laude', 'B.S.E., 2009, Princeton University', 'CLERKSHIPS', 'Hon. Timothy B. Dyk, Federal Circuit Court of Appeals', 'ADMITTED ONLY IN', 'New York']
# Sharonmoyee Goswami
# sgoswami@cravath.com
# LITIGATION
# +1-212-474-1928
# Partner
# https://www.cravath.com/people/index.html?f=20&po=5499&s=20
# --------------------------------------------------------------------
# ['Mark I. Greene', 'CORPORATE', 'Partner', 'mgreene@cravath.com', '+1-212-474-1150', 'Download vCard', 'EDUCATION', 'J.D., 1993, University of Pennsylvania Law School', 'B.A., 1989, Cornell University', 'CLERKSHIPS', 'Hon. Charles A. Legge, U.S.D.C. for the Northern District of California', 'ADMITTED ONLY IN', 'New York']
# Mark I. Greene
# mgreene@cravath.com
# CORPORATE
# +1-212-474-1150
# Partner
# https://www.cravath.com/people/index.html?f=20&po=5499&s=20
# --------------------------------------------------------------------
# ['Aaron M. Gruber', 'CORPORATE', 'Partner', 'agruber@cravath.com', '+1-212-474-1456', 'Download vCard', 'EDUCATION', 'J.D., 2007, Stanford Law School', 'Order of the Coif', 'M.Phil., 2004, University of Cambridge', 'Gates Cambridge Scholar', 'B.S., 2003, Yale College', 'summa cum laude', 'ADMITTED ONLY IN', 'New York']
# Aaron M. Gruber
# agruber@cravath.com
# CORPORATE
# +1-212-474-1456
# Partner
# https://www.cravath.com/people/index.html?f=20&po=5499&s=20
# --------------------------------------------------------------------
# ['Benjamin Gruenstein', 'LITIGATION', 'Partner', 'bgruenstein@cravath.com', '+1-212-474-1080', 'Download vCard', 'EDUCATION', 'J.D., 1999, Harvard Law School', 'magna cum laude', 'A.B., 1996, Harvard College', 'Phi Beta Kappa, summa cum laude', 'CLERKSHIPS', 'Hon. David H. Souter, U.S. Supreme Court', 'Hon. Stephen F. Williams, U.S. Court of Appeals for the D.C. Circuit', 'ADMITTED ONLY IN', 'New York']
# Benjamin Gruenstein
# bgruenstein@cravath.com
# LITIGATION
# +1-212-474-1080
# Partner
# https://www.cravath.com/people/index.html?f=20&po=5499&s=20
# --------------------------------------------------------------------
# ['C. Daniel Haaren', 'CORPORATE', 'Partner', 'dhaaren@cravath.com', '+1-212-474-1322', 'Download vCard', 'EDUCATION', 'J.D., 2012, New York University School of Law', 'Order of the Coif, Pomeroy Scholar, magna cum laude', 'B.A., 2009, Duke University', 'ADMITTED ONLY IN', 'New York']
# C. Daniel Haaren
# dhaaren@cravath.com
# CORPORATE
# +1-212-474-1322
# Partner
# https://www.cravath.com/people/index.html?f=20&po=5499&s=20
# --------------------------------------------------------------------
# ############################################################################
# ['Richard Hall', 'CORPORATE', 'Partner', 'rhall@cravath.com', '+1-212-474-1293', 'Download vCard', 'EDUCATION', 'LL.M., 1988, Harvard Law School', 'LL.B., 1986, University of Melbourne Law School', 'with Honors', 'B.Com., 1984, University of Melbourne', 'with Honors', 'ADMITTED ONLY IN', 'New York']
# Richard Hall
# rhall@cravath.com
# CORPORATE
# +1-212-474-1293
# Partner
# https://www.cravath.com/people/index.html?f=40&po=5499&s=20
# --------------------------------------------------------------------
# ['O. Keith Hallam III', 'CORPORATE', 'Partner', 'khallam@cravath.com', '+1-212-474-1458', 'Download vCard', 'EDUCATION', 'J.D., 2007, University of Pennsylvania Law School', 'B.A., 2003, University of Pennsylvania', 'magna cum laude', 'ADMITTED ONLY IN', 'New York']
# O. Keith Hallam III
# khallam@cravath.com
# CORPORATE
# +1-212-474-1458
# Partner
# https://www.cravath.com/people/index.html?f=40&po=5499&s=20
# --------------------------------------------------------------------
# ['Damaris Hernández', 'LITIGATION', 'Partner', 'dhernandez@cravath.com', '+1-212-474-1486', 'Download vCard', 'EDUCATION', 'J.D., 2007, New York University School of Law', 'An-Bryce Scholar', 'A.B., 2003, Harvard College', 'magna cum laude', 'ADMITTED ONLY IN', 'New York']
# Damaris Hernández
# dhernandez@cravath.com
# LITIGATION
# +1-212-474-1486
# Partner
# https://www.cravath.com/people/index.html?f=40&po=5499&s=20
# --------------------------------------------------------------------
# ['Eric W. Hilfers', 'EXECUTIVE COMPENSATION AND BENEFITS', 'Partner', 'ehilfers@cravath.com', '+1-212-474-1352', 'Download vCard', 'EDUCATION', 'J.D., 1998, University of Chicago Law School', 'with Honors', 'A.B., 1995, Princeton University', 'ADMITTED ONLY IN', 'New York']
# Eric W. Hilfers
# ehilfers@cravath.com
# EXECUTIVE COMPENSATION AND BENEFITS
# +1-212-474-1352
# Partner
# https://www.cravath.com/people/index.html?f=40&po=5499&s=20
# --------------------------------------------------------------------
# ['Jenny Hochenberg', 'CORPORATE', 'Partner', 'jhochenberg@cravath.com', '+1-212-474-1235', 'Download vCard', 'EDUCATION', 'J.D., 2009, Stanford Law School', 'with distinction', 'A.B., 2006, Dartmouth College', 'summa cum laude', 'ADMITTED ONLY IN', 'New York']
# Jenny Hochenberg
# jhochenberg@cravath.com
# CORPORATE
# +1-212-474-1235
# Partner
# https://www.cravath.com/people/index.html?f=40&po=5499&s=20
# --------------------------------------------------------------------
# ['Keith R. Hummel', 'LITIGATION', 'Partner', 'khummel@cravath.com', '+1-212-474-1772', 'Download vCard', 'EDUCATION', 'J.D., 1990, Georgetown University Law Center', 'Order of the Coif, magna cum laude', 'B.A., 1987, University of Notre Dame', 'ADMITTED ONLY IN', 'New York']
# Keith R. Hummel
# khummel@cravath.com
# LITIGATION
# +1-212-474-1772
# Partner
# https://www.cravath.com/people/index.html?f=40&po=5499&s=20
# --------------------------------------------------------------------
# ['Matthew G. Jones', 'CORPORATE', 'Partner', 'mjones@cravath.com', '+1-212-474-1298', 'Download vCard', 'EDUCATION', 'J.D., 2013, Columbia Law School', 'Harlan Fiske Stone Scholar; James Kent Scholar', 'B.A., 2010, Cornell University', 'ADMITTED ONLY IN', 'New York']
# Matthew G. Jones
# mjones@cravath.com
# CORPORATE
# +1-212-474-1298
# Partner
# https://www.cravath.com/people/index.html?f=40&po=5499&s=20
# --------------------------------------------------------------------
# ['David J. Kappos', 'CORPORATE', 'Partner', 'dkappos@cravath.com', '+1-212-474-1168', 'Download vCard', 'EDUCATION', 'J.D., 1990, University of California, Berkeley, School of Law', 'B.S., 1983, University of California, Davis', 'ADMITTED ONLY IN', 'New York', 'California', 'District of Columbia']
# David J. Kappos
# dkappos@cravath.com
# CORPORATE
# +1-212-474-1168
# Partner
# https://www.cravath.com/people/index.html?f=40&po=5499&s=20
# --------------------------------------------------------------------
# ['Jonathan J. Katz', 'EXECUTIVE COMPENSATION AND BENEFITS', 'Partner', 'jkatz@cravath.com', '+1-212-474-1538', 'Download vCard', 'EDUCATION', 'LL.M., 2013, New York University School of Law', 'J.D., 2007, Benjamin N. Cardozo School of Law', 'Order of the Coif, Dean’s Distinguished Scholar, summa cum laude', 'B.S., 2003, Cornell University', 'ADMITTED ONLY IN', 'New York']
# Jonathan J. Katz
# jkatz@cravath.com
# EXECUTIVE COMPENSATION AND BENEFITS
# +1-212-474-1538
# Partner
# https://www.cravath.com/people/index.html?f=40&po=5499&s=20
# --------------------------------------------------------------------
# ['Matthew M. Kelly', 'CORPORATE', 'Partner', 'mkelly@cravath.com', '+1-212-474-1318', 'Download vCard', 'EDUCATION', 'J.D., 2013, New York University School of Law', 'Pomeroy Scholar, magna cum laude', 'A.B., 2006, Dartmouth College', 'cum laude', 'ADMITTED ONLY IN', 'New York']
# Matthew M. Kelly
# mkelly@cravath.com
# CORPORATE
# +1-212-474-1318
# Partner
# https://www.cravath.com/people/index.html?f=40&po=5499&s=20
# --------------------------------------------------------------------
# ['Lauren Roberta Kennedy', 'LITIGATION', 'Partner', 'lkennedy@cravath.com', '+1-212-474-1650', 'Download vCard', 'EDUCATION', 'J.D., 2010, Columbia Law School', 'James Kent Scholar; Harlan Fiske Stone Scholar', 'B.A., 2007, Georgetown University', 'First Honors, Phi Beta Kappa, summa cum laude', 'CLERKSHIPS', 'Hon. Robert S. Smith, New York State Court of Appeals', 'ADMITTED ONLY IN', 'New York']
# Lauren Roberta Kennedy
# lkennedy@cravath.com
# LITIGATION
# +1-212-474-1650
# Partner
# https://www.cravath.com/people/index.html?f=40&po=5499&s=20
# --------------------------------------------------------------------
# ['Stephen M. Kessing', 'CORPORATE', 'Partner', 'skessing@cravath.com', '+1-212-474-1152', 'Download vCard', 'EDUCATION', 'J.D., 2005, Duke Law School', 'M.B.A., 2001, University of Southern California', 'B.S., 1995, Miami University of Ohio', 'ADMITTED ONLY IN', 'New York']
# Stephen M. Kessing
# skessing@cravath.com
# CORPORATE
# +1-212-474-1152
# Partner
# https://www.cravath.com/people/index.html?f=40&po=5499&s=20
# --------------------------------------------------------------------
# ['David H. Korn', 'LITIGATION', 'Partner', 'dkorn@cravath.com', '+1-212-474-1478', 'Download vCard', 'EDUCATION', 'J.D., 2013, Harvard Law School', 'magna cum laude', 'A.B., 2008, Princeton University', 'Honors', 'CLERKSHIPS', 'Hon. Stanley Marcus, U.S. Court of Appeals for the Eleventh Circuit', 'ADMITTED ONLY IN', 'New York', 'Florida']
# David H. Korn
# dkorn@cravath.com
# LITIGATION
# +1-212-474-1478
# Partner
# https://www.cravath.com/people/index.html?f=40&po=5499&s=20
# --------------------------------------------------------------------
# ['Tatiana Lapushchik', 'CORPORATE', 'Partner', 'tlapushchik@cravath.com', '+1-212-474-1442', 'Download vCard', 'EDUCATION', 'J.D., 2000, Harvard Law School', 'cum laude', 'B.A., 1997, Barnard College', 'summa cum laude', 'ADMITTED ONLY IN', 'New York']
# Tatiana Lapushchik
# tlapushchik@cravath.com
# CORPORATE
# +1-212-474-1442
# Partner
# https://www.cravath.com/people/index.html?f=40&po=5499&s=20
# --------------------------------------------------------------------
# ['Vanessa A. Lavely', 'LITIGATION', 'Partner', 'vlavely@cravath.com', '+1-212-474-1718', 'Download vCard', 'EDUCATION', 'J.D., 2008, UCLA School of Law', 'Order of the Coif', 'A.B., 2004, Harvard College', 'magna cum laude', 'CLERKSHIPS', 'Hon. Kim M. Wardlaw, U.S. Court of Appeals for the Ninth Circuit', 'ADMITTED ONLY IN', 'New York']
# Vanessa A. Lavely
# vlavely@cravath.com
# LITIGATION
# +1-212-474-1718
# Partner
# https://www.cravath.com/people/index.html?f=40&po=5499&s=20
# --------------------------------------------------------------------
# ['Rory A. Leraris', 'LITIGATION', 'Partner', 'rleraris@cravath.com', '+1-212-474-1257', 'Download vCard', 'EDUCATION', 'J.D., 2008, University of Chicago Law School', 'B.A., 2003, Amherst College', 'magna cum laude', 'ADMITTED ONLY IN', 'New York', 'New Jersey']
# Rory A. Leraris
# rleraris@cravath.com
# LITIGATION
# +1-212-474-1257
# Partner
# https://www.cravath.com/people/index.html?f=40&po=5499&s=20
# --------------------------------------------------------------------
# ['G.J. Ligelis Jr.', 'CORPORATE', 'Partner', 'gligelisjr@cravath.com', '+1-212-474-1892', 'Download vCard', 'EDUCATION', 'J.D., 2009, Harvard Law School', 'cum laude', 'A.B., 2006, Princeton University', 'Phi Beta Kappa, magna cum laude', 'ADMITTED ONLY IN', 'New York']
# G.J. Ligelis Jr.
# gligelisjr@cravath.com
# CORPORATE
# +1-212-474-1892
# Partner
# https://www.cravath.com/people/index.html?f=40&po=5499&s=20
# --------------------------------------------------------------------
# ['Michael E. Mariani', 'CORPORATE', 'Partner', 'mmariani@cravath.com', '+1-212-474-1007', 'Download vCard', 'EDUCATION', 'J.D., 2009, Columbia Law School', 'Harlan Fiske Stone Scholar', 'M.B.A., 2009, Columbia University', 'B.A., 2004, Tufts University', 'Phi Beta Kappa, summa cum laude', 'ADMITTED ONLY IN', 'New York']
# Michael E. Mariani
# mmariani@cravath.com
# CORPORATE
# +1-212-474-1007
# Partner
# https://www.cravath.com/people/index.html?f=40&po=5499&s=20
# --------------------------------------------------------------------
# ['David R. Marriott', 'LITIGATION', 'Partner', 'dmarriott@cravath.com', '+1-212-474-1430', 'Download vCard', 'EDUCATION', 'J.D., 1994, New York University School of Law', 'B.A., 1991, Brigham Young University', 'magna cum laude', 'CLERKSHIPS', 'Hon. Albert J. Engel, U.S. Court of Appeals for the Sixth Circuit', 'Hon. Eugene F. Lynch, U.S.D.C. for the Northern District of California', 'ADMITTED ONLY IN', 'New York', 'Utah']
# David R. Marriott
# dmarriott@cravath.com
# LITIGATION
# +1-212-474-1430
# Partner
# https://www.cravath.com/people/index.html?f=40&po=5499&s=20
# --------------------------------------------------------------------
# ['Darin P. McAtee', 'LITIGATION', 'Partner', 'dmcatee@cravath.com', '+1-212-474-1480', 'Download vCard', 'EDUCATION', 'J.D., 1991, Harvard Law School', 'magna cum laude', 'B.A., 1988, University of Kansas', 'summa cum laude', 'CLERKSHIPS', 'Hon. Stanley F. Birch, Jr., U.S. Court of Appeals for the Eleventh Circuit', 'ADMITTED ONLY IN', 'New York']
# Darin P. McAtee
# dmcatee@cravath.com
# LITIGATION
# +1-212-474-1480
# Partner
# https://www.cravath.com/people/index.html?f=40&po=5499&s=20
# --------------------------------------------------------------------
# ############################################################################
# ['David Mercado', 'CORPORATE', 'Partner', 'dmercado@cravath.com', '+1-212-474-1756', 'Download vCard', 'EDUCATION', "M.A., 2021, King's College London", 'J.D., 1984, Yale Law School', 'A.B., 1981, Columbia College', 'ADMITTED ONLY IN', 'New York']
# David Mercado
# dmercado@cravath.com
# CORPORATE
# +1-212-474-1756
# Partner
# https://www.cravath.com/people/index.html?f=60&po=5499&s=20
# --------------------------------------------------------------------
# ['Matthew Morreale', 'CORPORATE', 'Partner', 'mmorreale@cravath.com', '+1-212-474-1534', 'Download vCard', 'EDUCATION', 'J.D., 1997, Columbia Law School', 'Harlan Fiske Stone Scholar', 'M.S., 1994, University of Pennsylvania', 'B.A., 1990, University of Pennsylvania', 'B.A.S., 1990, University of Pennsylvania', 'ADMITTED ONLY IN', 'New York']
# Matthew Morreale
# mmorreale@cravath.com
# CORPORATE
# +1-212-474-1534
# Partner
# https://www.cravath.com/people/index.html?f=60&po=5499&s=20
# --------------------------------------------------------------------
# ['Lauren A. Moskowitz', 'LITIGATION', 'Partner', 'lmoskowitz@cravath.com', '+1-212-474-1648', 'Download vCard', 'EDUCATION', 'J.D., 2005, Fordham University School of Law', 'B.A., 2002, Cornell University', 'CLERKSHIPS', 'Hon. Shira Ann Scheindlin, U.S.D.C. for the Southern District of New York', 'ADMITTED ONLY IN', 'New York']
# Lauren A. Moskowitz
# lmoskowitz@cravath.com
# LITIGATION
# +1-212-474-1648
# Partner
# https://www.cravath.com/people/index.html?f=60&po=5499&s=20
# --------------------------------------------------------------------
# ['Omid H. Nasab', 'LITIGATION', 'Partner', 'onasab@cravath.com', '+1-212-474-1972', 'Download vCard', 'EDUCATION', 'J.D., 2006, Columbia Law School', 'Harlan Fiske Stone Scholar', 'A.B., 2002, Duke University', 'CLERKSHIPS', 'Hon. Deborah L. Cook, U.S. Court of Appeals for the Sixth Circuit', 'Hon. Bruce W. Kauffman, U.S.D.C. for the Eastern District of Pennsylvania', 'ADMITTED ONLY IN', 'New York']
# Omid H. Nasab
# onasab@cravath.com
# LITIGATION
# +1-212-474-1972
# Partner
# https://www.cravath.com/people/index.html?f=60&po=5499&s=20
# --------------------------------------------------------------------
# ['Andrew W. Needham', 'TAX', 'Partner', 'aneedham@cravath.com', '+1-212-474-1440', 'Download vCard', 'EDUCATION', 'M.B.A., 1992, The Wharton School, University of Pennsylvania', 'LL.M., 1990, Georgetown University Law Center', 'J.D., 1986, Georgetown University Law Center', 'B.A., 1982, University of Arizona College of Law', 'ADMITTED ONLY IN', 'New York']
# Andrew W. Needham
# aneedham@cravath.com
# TAX
# +1-212-474-1440
# Partner
# https://www.cravath.com/people/index.html?f=60&po=5499&s=20
# --------------------------------------------------------------------
# ['Evan Norris', 'LITIGATION', 'Partner', 'enorris@cravath.com', '+1-212-474-1524', 'Download vCard', 'EDUCATION', 'J.D., 2002, Harvard Law School', 'B.A., 1999, Columbia College', 'magna cum laude', 'CLERKSHIPS', 'Hon. Richard M. Berman, U.S.D.C. for the Southern District of New York', 'ADMITTED ONLY IN', 'New York']
# Evan Norris
# enorris@cravath.com
# LITIGATION
# +1-212-474-1524
# Partner
# https://www.cravath.com/people/index.html?f=60&po=5499&s=20
# --------------------------------------------------------------------
# ['Julie A. North', 'LITIGATION', 'Partner', 'jnorth@cravath.com', '+1-212-474-1752', 'Download vCard', 'EDUCATION', 'J.D., 1989, Syracuse University College of Law', 'magna cum laude', 'B.A., 1984, Hamilton College', 'cum laude', 'ADMITTED ONLY IN', 'New York']
# Julie A. North
# jnorth@cravath.com
# LITIGATION
# +1-212-474-1752
# Partner
# https://www.cravath.com/people/index.html?f=60&po=5499&s=20
# --------------------------------------------------------------------
# ['Kevin J. Orsini', 'LITIGATION', 'Partner', 'korsini@cravath.com', '+1-212-474-1596', 'Download vCard', 'EDUCATION', 'J.D., 2003, New York University School of Law', 'cum laude', 'B.A., 2000, The George Washington University', 'Phi Beta Kappa, summa cum laude', 'ADMITTED ONLY IN', 'New York', 'New Jersey']
# Kevin J. Orsini
# korsini@cravath.com
# LITIGATION
# +1-212-474-1596
# Partner
# https://www.cravath.com/people/index.html?f=60&po=5499&s=20
# --------------------------------------------------------------------
# ['Michael A. Paskin', 'LITIGATION', 'Partner', 'mpaskin@cravath.com', '+1-212-474-1760', 'Download vCard', 'EDUCATION', 'J.D., 1995, Fordham University School of Law', 'B.A., 1992, University of Pennsylvania', 'cum laude', 'CLERKSHIPS', 'Hon. Paul J. Kelly, Jr., U.S. Court of Appeals for the Tenth Circuit', 'ADMITTED ONLY IN', 'New York']
# Michael A. Paskin
# mpaskin@cravath.com
# LITIGATION
# +1-212-474-1760
# Partner
# https://www.cravath.com/people/index.html?f=60&po=5499&s=20
# --------------------------------------------------------------------
# ['David J. Perkins', 'CORPORATE', 'Partner', 'dperkins@cravath.com', '+1-212-474-1708', 'Download vCard', 'EDUCATION', 'J.D., 2005, University of Washington School of Law', 'Order of the Coif, High Honors', 'B.S., 1997, United States Military Academy', 'Distinguished Honor', 'ADMITTED ONLY IN', 'New York']
# David J. Perkins
# dperkins@cravath.com
# CORPORATE
# +1-212-474-1708
# Partner
# https://www.cravath.com/people/index.html?f=60&po=5499&s=20
# --------------------------------------------------------------------
# ['Andrew J. Pitts', 'CORPORATE', 'Partner', 'apitts@cravath.com', '+1-212-474-1620', 'Download vCard', 'EDUCATION', 'M.B.A., 1995, Boston University', 'with High Honors', 'J.D., 1994, Boston University School of Law', 'summa cum laude', 'B.A., 1988, Trinity College', 'ADMITTED ONLY IN', 'New York']
# Andrew J. Pitts
# apitts@cravath.com
# CORPORATE
# +1-212-474-1620
# Partner
# https://www.cravath.com/people/index.html?f=60&po=5499&s=20
# --------------------------------------------------------------------
# ['David L. Portilla', 'CORPORATE', 'Partner', 'dportilla@cravath.com', '+1-212-474-1410', 'Download vCard', 'EDUCATION', 'J.D., 2006, Rutgers Law School - Newark', 'Highest Honors; Order of the Coif', 'B.A., 2002, Rutgers University', 'with Honors', 'ADMITTED ONLY IN', 'New York', 'District of Columbia']
# David L. Portilla
# dportilla@cravath.com
# CORPORATE
# +1-212-474-1410
# Partner
# https://www.cravath.com/people/index.html?f=60&po=5499&s=20
# --------------------------------------------------------------------
# ['Michael T. Reynolds', 'LITIGATION', 'Partner', 'mreynolds@cravath.com', '+1-212-474-1552', 'Download vCard', 'EDUCATION', 'J.D., 1995, Yale Law School', 'M.Phil., 1991, University of Cambridge', 'Keasbey Scholar', 'A.B., 1990, Dartmouth College', 'Phi Beta Kappa, magna cum laude', 'CLERKSHIPS', "Hon. Diarmuid F. O'Scannlain, U.S. Court of Appeals for the Ninth Circuit", 'ADMITTED ONLY IN', 'New York']
# Michael T. Reynolds
# mreynolds@cravath.com
# LITIGATION
# +1-212-474-1552
# Partner
# https://www.cravath.com/people/index.html?f=60&po=5499&s=20
# --------------------------------------------------------------------
# ['Lauren M. Rosenberg', 'LITIGATION', 'Partner', 'lrosenberg@cravath.com', '+1-212-474-1159', 'Download vCard', 'EDUCATION', 'J.D., 2011, Columbia Law School', 'Harlan Fiske Stone Scholar', 'B.A., 2008, University of Pennsylvania', 'Phi Beta Kappa, summa cum laude', 'CLERKSHIPS', 'Hon. Lewis A. Kaplan, U.S.D.C. for the Southern District of New York', 'ADMITTED ONLY IN', 'New York']
# Lauren M. Rosenberg
# lrosenberg@cravath.com
# LITIGATION
# +1-212-474-1159
# Partner
# https://www.cravath.com/people/index.html?f=60&po=5499&s=20
# --------------------------------------------------------------------
# ['Sasha Rosenthal-Larrea', 'CORPORATE', 'Partner', 'srosenthal-larrea@cravath.com', '+1-212-474-1967', 'Download vCard', 'EDUCATION', 'J.D., 2010, Columbia Law School', 'Harlan Fiske Stone Scholar', 'A.B., 2007, Brown University', 'ADMITTED ONLY IN', 'New York']
# Sasha Rosenthal-Larrea
# srosenthal-larrea@cravath.com
# CORPORATE
# +1-212-474-1967
# Partner
# https://www.cravath.com/people/index.html?f=60&po=5499&s=20
# --------------------------------------------------------------------
# ['Antony L. Ryan', 'LITIGATION', 'Partner', 'aryan@cravath.com', '+1-212-474-1296', 'Download vCard', 'EDUCATION', 'J.D., 1995, Harvard Law School', 'magna cum laude', 'B.A., 1992, Yale College', 'Phi Beta Kappa, summa cum laude', 'CLERKSHIPS', 'Hon. Judith W. Rogers, U.S. Court of Appeals for the D.C. Circuit', 'ADMITTED ONLY IN', 'New York']
# Antony L. Ryan
# aryan@cravath.com
# LITIGATION
# +1-212-474-1296
# Partner
# https://www.cravath.com/people/index.html?f=60&po=5499&s=20
# --------------------------------------------------------------------
# ['Faiza J. Saeed', 'CORPORATE', 'Partner', 'fsaeed@cravath.com', '+1-212-474-1454', 'Download vCard', 'EDUCATION', 'J.D., 1991, Harvard Law School', 'magna cum laude', 'B.A., 1987, University of California at Berkeley', 'with Highest Distinction, Phi Beta Kappa', 'ADMITTED ONLY IN', 'New York', 'California (Inactive)', 'District of Columbia (Inactive)']
# Faiza J. Saeed
# fsaeed@cravath.com
# CORPORATE
# +1-212-474-1454
# Partner
# https://www.cravath.com/people/index.html?f=60&po=5499&s=20
# --------------------------------------------------------------------
# ['George F. Schoen', 'CORPORATE', 'Partner', 'gschoen@cravath.com', '+1-212-474-1740', 'Download vCard', 'EDUCATION', 'J.D., 1998, University of Chicago Law School', 'with Honors', 'B.A., 1994, Cornell University', 'ADMITTED ONLY IN', 'New York']
# George F. Schoen
# gschoen@cravath.com
# CORPORATE
# +1-212-474-1740
# Partner
# https://www.cravath.com/people/index.html?f=60&po=5499&s=20
# --------------------------------------------------------------------
# ['Margaret T. Segall', 'LITIGATION', 'Partner', 'msegall@cravath.com', '+1-212-474-1231', 'Download vCard', 'EDUCATION', 'J.D., 2008, Harvard Law School', 'cum laude', 'A.B., 2003, Harvard College', 'magna cum laude', 'ADMITTED ONLY IN', 'New York']
# Margaret T. Segall
# msegall@cravath.com
# LITIGATION
# +1-212-474-1231
# Partner
# https://www.cravath.com/people/index.html?f=60&po=5499&s=20
# --------------------------------------------------------------------
# ['Rachel G. Skaistis', 'LITIGATION', 'Partner', 'rskaistis@cravath.com', '+1-212-474-1934', 'Download vCard', 'EDUCATION', 'J.D., 1997, Cornell Law School', 'cum laude', 'B.A., 1992, Yale College', 'CLERKSHIPS', 'Hon. Shira Ann Scheindlin, U.S.D.C. for the Southern District of New York', 'ADMITTED ONLY IN', 'New York']
# Rachel G. Skaistis
# rskaistis@cravath.com
# LITIGATION
# +1-212-474-1934
# Partner
# https://www.cravath.com/people/index.html?f=60&po=5499&s=20
# --------------------------------------------------------------------
# ############################################################################
# ['Daniel Slifkin', 'LITIGATION', 'Partner', 'dslifkin@cravath.com', '+1-212-474-1438', 'Download vCard', 'EDUCATION', 'J.D., 1991, Harvard Law School', 'Sears Prize, magna cum laude', 'B.C.L., 1988, University of Oxford', 'First Class Honors', 'B.A., 1987, University of Oxford', 'First Class honors, Martin Wronker Prize (Torts)', 'ADMITTED ONLY IN', 'New York']
# Daniel Slifkin
# dslifkin@cravath.com
# LITIGATION
# +1-212-474-1438
# Partner
# https://www.cravath.com/people/index.html?f=80&po=5499&s=20
# --------------------------------------------------------------------
# ['Richard J. Stark', 'LITIGATION', 'Partner', 'rstark@cravath.com', '+1-212-474-1564', 'Download vCard', 'EDUCATION', 'M.S., 2014, Columbia University', 'J.D., 1991, New York University School of Law', 'A.B., 1986, Harvard University', 'ADMITTED ONLY IN', 'New York', 'Arizona', 'California', 'Connecticut']
# Richard J. Stark
# rstark@cravath.com
# LITIGATION
# +1-212-474-1564
# Partner
# https://www.cravath.com/people/index.html?f=80&po=5499&s=20
# --------------------------------------------------------------------
# ['George A. Stephanakis', 'CORPORATE', 'Partner', 'gstephanakis@cravath.com', '+44-20-7453-1040', 'Download vCard', 'EDUCATION', 'LL.M., 1997, Harvard Law School', 'Fulbright Scholar', 'LL.M., 1995, Cambridge University - Faculty of Law', 'LL.B., 1994, University of Athens', 'summa cum laude', 'ADMITTED ONLY IN', 'New York']
# George A. Stephanakis
# gstephanakis@cravath.com
# CORPORATE
# +44-20-7453-1040
# Partner
# https://www.cravath.com/people/index.html?f=80&po=5499&s=20
# --------------------------------------------------------------------
# ['David M. Stuart', 'LITIGATION', 'Partner', 'dstuart@cravath.com', '+1-212-474-1519', 'Download vCard', 'EDUCATION', 'J.D., 1995, New York University School of Law', 'B.A., 1990, Wesleyan University', 'Phi Beta Kappa, High Honors', 'CLERKSHIPS', 'Hon. John Gleeson, U.S.D.C. for the Eastern District of New York', 'ADMITTED ONLY IN', 'New York', 'Connecticut']
# David M. Stuart
# dstuart@cravath.com
# LITIGATION
# +1-212-474-1519
# Partner
# https://www.cravath.com/people/index.html?f=80&po=5499&s=20
# --------------------------------------------------------------------
# ['Brittany L. Sukiennik', 'LITIGATION', 'Partner', 'bsukiennik@cravath.com', '+1-212-474-1946', 'Download vCard', 'EDUCATION', 'J.D., 2011, Columbia Law School', 'James Kent Scholar, Ginsburg Scholar', 'B.A., 2007, The University of Texas at Austin', 'Phi Beta Kappa, summa cum laude', 'CLERKSHIPS', 'Hon. Vernon S. Broderick, U.S.D.C. for the Southern District of New York', 'Hon. Cathy Seibel, U.S.D.C. for the Southern District of New York', 'ADMITTED ONLY IN', 'New York']
# Brittany L. Sukiennik
# bsukiennik@cravath.com
# LITIGATION
# +1-212-474-1946
# Partner
# https://www.cravath.com/people/index.html?f=80&po=5499&s=20
# --------------------------------------------------------------------
# ['Erik R. Tavzel', 'CORPORATE', 'Partner', 'etavzel@cravath.com', '+1-212-474-1796', 'Download vCard', 'EDUCATION', 'J.D., 1998, University of Michigan Law School', 'cum laude', 'S.B., 1993, Massachusetts Institute of Technology', 'ADMITTED ONLY IN', 'New York']
# Erik R. Tavzel
# etavzel@cravath.com
# CORPORATE
# +1-212-474-1796
# Partner
# https://www.cravath.com/people/index.html?f=80&po=5499&s=20
# --------------------------------------------------------------------
# ['J. Leonard Teti II', 'TAX', 'Partner', 'lteti@cravath.com', '+1-212-474-1896', 'Download vCard', 'EDUCATION', 'J.D., 2005, University of Virginia School of Law', 'Order of the Coif', 'A.B., 1999, Princeton University', 'with Honors', 'ADMITTED ONLY IN', 'New York']
# J. Leonard Teti II
# lteti@cravath.com
# TAX
# +1-212-474-1896
# Partner
# https://www.cravath.com/people/index.html?f=80&po=5499&s=20
# --------------------------------------------------------------------
# ['Robert I. Townsend III', 'CORPORATE', 'Partner', 'rtownsend@cravath.com', '+1-212-474-1964', 'Download vCard', 'EDUCATION', 'J.D., 1990, Harvard Law School', 'magna cum laude', 'A.B., 1987, Harvard College', 'magna cum laude', 'ADMITTED ONLY IN', 'New York']
# Robert I. Townsend III
# rtownsend@cravath.com
# CORPORATE
# +1-212-474-1964
# Partner
# https://www.cravath.com/people/index.html?f=80&po=5499&s=20
# --------------------------------------------------------------------
# ['Minh Van Ngo', 'CORPORATE', 'Partner', 'mngo@cravath.com', '+1-212-474-1465', 'Download vCard', 'EDUCATION', 'J.D., 2001, Yale Law School', 'B.A., 1998, Duke University', 'summa cum laude', 'ADMITTED ONLY IN', 'New York']
# Minh Van Ngo
# mngo@cravath.com
# CORPORATE
# +1-212-474-1465
# Partner
# https://www.cravath.com/people/index.html?f=80&po=5499&s=20
# --------------------------------------------------------------------
# ['Christine A. Varney', 'LITIGATION', 'Partner', 'cvarney@cravath.com', '+1-212-474-1140', 'Download vCard', 'EDUCATION', 'J.D., 1986, Georgetown University Law Center', 'M.P.A., 1982, Syracuse University', 'B.A., 1977, State University of New York, Albany', 'ADMITTED ONLY IN', 'New York', 'District of Columbia']
# Christine A. Varney
# cvarney@cravath.com
# LITIGATION
# +1-212-474-1140
# Partner
# https://www.cravath.com/people/index.html?f=80&po=5499&s=20
# --------------------------------------------------------------------
# ['Andrew M. Wark', 'CORPORATE', 'Partner', 'awark@cravath.com', '+1-212-474-1592', 'Download vCard', 'EDUCATION', 'J.D., 2013, Columbia Law School', 'Harlan Fiske Stone Scholar', 'B.S., 2010, Duke University', 'ADMITTED ONLY IN', 'New York']
# Andrew M. Wark
# awark@cravath.com
# CORPORATE
# +1-212-474-1592
# Partner
# https://www.cravath.com/people/index.html?f=80&po=5499&s=20
# --------------------------------------------------------------------
# ['Allison M. Wein', 'CORPORATE', 'Partner', 'awein@cravath.com', '+1-212-474-1918', 'Download vCard', 'EDUCATION', 'J.D., 2010, Northwestern University School of Law', 'cum laude', 'B.A., 2004, University of Pennsylvania', 'magna cum laude', 'ADMITTED ONLY IN', 'New York']
# Allison M. Wein
# awein@cravath.com
# CORPORATE
# +1-212-474-1918
# Partner
# https://www.cravath.com/people/index.html?f=80&po=5499&s=20
# --------------------------------------------------------------------
# ['John W. White', 'CORPORATE', 'Partner', 'jwhite@cravath.com', '+1-212-474-1732', 'Download vCard', 'EDUCATION', 'J.D., 1973, New York University School of Law', 'Order of the Coif, magna cum laude', 'B.S., 1970, University of Virginia', 'with Honors', 'CLERKSHIPS', 'Hon. John J. Gibbons, U.S. Court of Appeals for the Third Circuit', 'ADMITTED ONLY IN', 'New York']
# John W. White
# jwhite@cravath.com
# CORPORATE
# +1-212-474-1732
# Partner
# https://www.cravath.com/people/index.html?f=80&po=5499&s=20
# ...
# ['LizabethAnn R. Eisen', 'CORPORATE', 'Retired Partner', 'lizann.eisen@cravath.com', '+1-212-474-1930', 'Download vCard', 'EDUCATION', 'J.D., 1997, University of Pennsylvania Law School', 'B.A., 1994, Cornell University']
# LizabethAnn R. Eisen
# lizann.eisen@cravath.com
# CORPORATE
# +1-212-474-1930
# Retired partner
# https://www.cravath.com/people/index.html?po=5480&s=20
# --------------------------------------------------------------------
# ['Allen Finkelson', 'CORPORATE', 'Retired Partner', 'afinkelson@cravath.com', '+1-212-474-1262', 'Download vCard', 'EDUCATION', 'J.D., 1971, Columbia Law School', 'magna cum laude', 'B.A., 1968, St. Lawrence University', 'Phi Beta Kappa, magna cum laude']
# Allen Finkelson
# afinkelson@cravath.com
# CORPORATE
# +1-212-474-1262
# Retired partner
# https://www.cravath.com/people/index.html?po=5480&s=20
# --------------------------------------------------------------------
# ['Philip A. Gelston', 'OFFICE OF THE GENERAL COUNSEL', 'Retired Partner', 'pgelston@cravath.com', '+1-212-474-1548', 'Download vCard', 'EDUCATION', 'J.D., 1977, Harvard Law School', 'Sears Prize, magna cum laude', 'A.B., 1974, Harvard College', 'Phi Beta Kappa, cum laude', 'CLERKSHIPS', 'Hon. John Minor Wisdom, U.S. Court of Appeals for the Fifth Circuit', 'ADMITTED ONLY IN', 'New York']
# Philip A. Gelston
# pgelston@cravath.com
# OFFICE OF THE GENERAL COUNSEL
# +1-212-474-1548
# Retired partner
# https://www.cravath.com/people/index.html?po=5480&s=20
# --------------------------------------------------------------------
# ['Stuart W. Gold', 'LITIGATION', 'Retired Partner', 'sgold@cravath.com', '+1-212-474-1394', 'Download vCard', 'EDUCATION', 'J.D., 1972, New York University School of Law', 'Order of the Coif, John Norton Pomeroy Scholar, cum laude', 'B.A., 1969, Brooklyn College', 'CLERKSHIPS', 'Hon. Edward Weinfeld, U.S.D.C. for the Southern District of New York']
# Stuart W. Gold
# sgold@cravath.com
# LITIGATION
# +1-212-474-1394
# Retired partner
# https://www.cravath.com/people/index.html?po=5480&s=20
# --------------------------------------------------------------------
# ['David Greenwald', 'LITIGATION', 'Retired Partner', 'dgreenwald@cravath.com', '+1-212-474-1922', 'Download vCard', 'EDUCATION', 'J.D., 1993, University of Chicago Law School', 'with High Honors, Order of the Coif, Bustin Prize', 'B.A., 1990, Harvard University', 'Phi Beta Kappa, summa cum laude', 'CLERKSHIPS', 'Hon. Richard A. Posner, U.S. Court of Appeals for the Seventh Circuit']
# David Greenwald
# dgreenwald@cravath.com
# LITIGATION
# +1-212-474-1922
# Retired partner
# https://www.cravath.com/people/index.html?po=5480&s=20
# --------------------------------------------------------------------
# ['Kevin J. Grehan', 'CORPORATE', 'Retired Partner', 'kgrehan@cravath.com', 'Download vCard', 'EDUCATION', 'J.D., 1981, Columbia Law School', 'Harlan Fiske Stone Scholar', 'B.A., 1978, Fordham University', 'Phi Beta Kappa, summa cum laude']
# Kevin J. Grehan
# kgrehan@cravath.com
# CORPORATE
# Null
# Retired partner
# https://www.cravath.com/people/index.html?po=5480&s=20
# --------------------------------------------------------------------
# ['Kris F. Heinzelman', 'CORPORATE', 'Retired Partner', 'kris.heinzelman@cravath.com', '+1-212-474-1336', 'Download vCard', 'EDUCATION', 'J.D., 1976, Yale Law School', 'M.A., 1973, Brown University', 'A.B., 1973, Brown University', 'Phi Beta Kappa, magna cum laude']
# Kris F. Heinzelman
# kris.heinzelman@cravath.com
# CORPORATE
# +1-212-474-1336
# Retired partner
# https://www.cravath.com/people/index.html?po=5480&s=20
# --------------------------------------------------------------------
# ############################################################################
# ['Alan J. Hruska', 'LITIGATION', 'Retired Partner', 'ahruska@cravath.com', '+1-212-474-1720', 'Download vCard', 'EDUCATION', 'LL.B., 1958, Yale Law School', 'B.A., 1955, Yale College']
# Alan J. Hruska
# ahruska@cravath.com
# LITIGATION
# +1-212-474-1720
# Retired partner
# https://www.cravath.com/people/index.html?f=20&po=5480&s=20
# --------------------------------------------------------------------
# ['B. Robbins Kiessling', 'CORPORATE', 'Retired Partner', 'bkiessling@cravath.com', '+1-212-474-1500', 'Download vCard', 'EDUCATION', 'J.D., 1976, New York University School of Law', 'Order of the Coif, cum laude', 'B.A., 1973, Yale College', 'cum laude', 'CLERKSHIPS', 'Hon. Edward Weinfeld, U.S.D.C. for the Southern District of New York']
# B. Robbins Kiessling
# bkiessling@cravath.com
# CORPORATE
# +1-212-474-1500
# Retired partner
# https://www.cravath.com/people/index.html?f=20&po=5480&s=20
# --------------------------------------------------------------------
# ['Collier Kirkham', 'CORPORATE', 'Retired Partner', 'ckirkham@cravath.com', '+1-212-474-1204', 'Download vCard', 'EDUCATION', 'J.D., 1975, University of Iowa College of Law', 'with Highest Distinction', 'M.S., 1971, Stanford University', 'A.B., 1969, Harvard College', 'magna cum laude']
# Collier Kirkham
# ckirkham@cravath.com
# CORPORATE
# +1-212-474-1204
# Retired partner
# https://www.cravath.com/people/index.html?f=20&po=5480&s=20
# --------------------------------------------------------------------
# ['Stephen S. Madsen', 'LITIGATION', 'Retired Partner', 'smadsen@cravath.com', '+1-212-474-1886', 'Download vCard', 'EDUCATION', 'J.D., 1980, Columbia Law School', 'Harlan Fiske Stone Scholar', 'B.A., 1973, Harvard College', 'magna cum laude', 'CLERKSHIPS', 'Hon. Amalya L. Kearse, U.S. Court of Appeals for the Second Circuit']
# Stephen S. Madsen
# smadsen@cravath.com
# LITIGATION
# +1-212-474-1886
# Retired partner
# https://www.cravath.com/people/index.html?f=20&po=5480&s=20
# --------------------------------------------------------------------
# ['Rory O. Millson', 'LITIGATION', 'Retired Partner', 'Download vCard', 'EDUCATION', 'J.D., 1977, Yale Law School', 'A.B., 1975, University of Oxford', 'First Class Honors, Rhodes Scholar', 'B.A., 1973, Yale College', 'summa cum laude']
# Rory O. Millson
# Null
# LITIGATION
# Null
# Retired partner
# https://www.cravath.com/people/index.html?f=20&po=5480&s=20
# --------------------------------------------------------------------
# ['David G. Ormsby', 'CORPORATE', 'Retired Partner', 'dormsby@cravath.com', '+1-212-474-1546', 'Download vCard', 'EDUCATION', 'LL.B., 1961, Harvard Law School', 'B.A., 1955, Amherst College', 'cum laude']
# David G. Ormsby
# dormsby@cravath.com
# CORPORATE
# +1-212-474-1546
# Retired partner
# https://www.cravath.com/people/index.html?f=20&po=5480&s=20
# --------------------------------------------------------------------
# ['Thomas G. Rafferty', 'LITIGATION', 'Retired Partner', 'trafferty@cravath.com', '+1-212-474-1837', 'Download vCard', 'EDUCATION', 'J.D., 1988, Harvard Law School', 'B.A., 1985, State University of New York, Old Westbury']
# Thomas G. Rafferty
# trafferty@cravath.com
# LITIGATION
# +1-212-474-1837
# Retired partner
# https://www.cravath.com/people/index.html?f=20&po=5480&s=20
# --------------------------------------------------------------------
# ['Robert S. Rifkind', 'LITIGATION', 'Retired Partner', 'rrifkind@cravath.com', '+1-212-474-1450', 'Download vCard', 'EDUCATION', 'J.D., 1961, Harvard Law School', 'cum laude', 'B.A., 1958, Yale College', 'summa cum laude']
# Robert S. Rifkind
# rrifkind@cravath.com
# LITIGATION
# +1-212-474-1450
# Retired partner
# https://www.cravath.com/people/index.html?f=20&po=5480&s=20
# --------------------------------------------------------------------
# ['William P. Rogers Jr.', 'CORPORATE', 'Retired Partner', 'wrogers@cravath.com', '+1-212-474-1270', 'Download vCard', 'EDUCATION', 'J.D., 1978, Case Western Reserve University School of Law', 'B.A., 1972, Union College', 'CLERKSHIPS', 'Hon. Paul C. Weick, U.S. Court of Appeals for the Sixth Circuit']
# William P. Rogers Jr.
# wrogers@cravath.com
# CORPORATE
# +1-212-474-1270
# Retired partner
# https://www.cravath.com/people/index.html?f=20&po=5480&s=20
# --------------------------------------------------------------------
# ['Ronald S. Rolfe', 'LITIGATION', 'Retired Partner', 'rrolfe@cravath.com', '+1-212-474-1714', 'Download vCard', 'EDUCATION', 'J.D., 1969, Columbia Law School', 'Stone Scholar, Kent Scholar, magna cum laude', 'A.B., 1966, Harvard College', 'cum laude', 'CLERKSHIPS', 'Hon. Marvin E. Frankel, U.S.D.C. for the Southern District of New York']
# Ronald S. Rolfe
# rrolfe@cravath.com
# LITIGATION
# +1-212-474-1714
# Retired partner
# https://www.cravath.com/people/index.html?f=20&po=5480&s=20
# --------------------------------------------------------------------
# ['Marc S. Rosenberg', 'CORPORATE', 'Retired Partner', 'mrosenberg@cravath.com', '+1-212-474-1676', 'Download vCard', 'EDUCATION', 'J.D., 1983, Harvard Law School', 'Sears Prize, magna cum laude', 'A.B., 1980, Princeton University', 'Phi Beta Kappa, summa cum laude', 'CLERKSHIPS', 'Hon. Walter R. Mansfield, U.S. Court of Appeals for the Second Circuit']
# Marc S. Rosenberg
# mrosenberg@cravath.com
# CORPORATE
# +1-212-474-1676
# Retired partner
# https://www.cravath.com/people/index.html?f=20&po=5480&s=20
# --------------------------------------------------------------------
# ['Paul C. Saunders', 'LITIGATION', 'Retired Partner', 'psaunders@cravath.com', '+1-212-474-1404', 'Download vCard', 'EDUCATION', 'M.S., 2017, New York University', 'With Distinction', 'J.D., 1966, Georgetown University Law Center', 'A.B., 1963, Fordham University', 'Phi Beta Kappa, Pi Sigma Alpha, egregia cum laude']
# Paul C. Saunders
# psaunders@cravath.com
# LITIGATION
# +1-212-474-1404
# Retired partner
# https://www.cravath.com/people/index.html?f=20&po=5480&s=20
# --------------------------------------------------------------------
# ['Frederick A. O. Schwarz Jr.', 'LITIGATION', 'Retired Partner', 'fschwarz@cravath.com', '+1-212-474-1444', 'Download vCard', 'EDUCATION', 'LL.B., 1960, Harvard Law School', 'magna cum laude', 'A.B., 1957, Harvard University', 'magna cum laude']
# Frederick A. O. Schwarz Jr.
# fschwarz@cravath.com
# LITIGATION
# +1-212-474-1444
# Retired partner
# https://www.cravath.com/people/index.html?f=20&po=5480&s=20
# --------------------------------------------------------------------
# ['Martin L. Senzel', 'CORPORATE', 'Retired Partner', 'msenzel@cravath.com', '+1-212-474-1520', 'Download vCard', 'EDUCATION', 'LL.B., 1969, Yale Law School', 'Order of the Coif', 'B.A., 1966, Yale College', 'Phi Beta Kappa, summa cum laude']
# Martin L. Senzel
# msenzel@cravath.com
# CORPORATE
# +1-212-474-1520
# Retired partner
# https://www.cravath.com/people/index.html?f=20&po=5480&s=20
# --------------------------------------------------------------------
# ['Gregory M. Shaw', 'CORPORATE', 'Retired Partner', 'gshaw@cravath.com', '+1-212-474-1902', 'Download vCard', 'EDUCATION', 'J.D., 1980, Columbia Law School', 'B.S., 1977, Columbia University', 'Phi Beta Kappa']
# Gregory M. Shaw
# gshaw@cravath.com
# CORPORATE
# +1-212-474-1902
# Retired partner
# https://www.cravath.com/people/index.html?f=20&po=5480&s=20
# --------------------------------------------------------------------
# ['Max R. Shulman', 'LITIGATION', 'Retired Partner', 'mshulman@cravath.com', '+1-212-474-1890', 'Download vCard', 'EDUCATION', 'J.D., 1970, Columbia Law School', 'Stone Scholar, Kent Scholar, cum laude', 'A.B., 1967, Harvard College', 'cum laude', 'CLERKSHIPS', 'Hon. Charles M. Metzner, U.S.D.C. for the Southern District of New York']
# Max R. Shulman
# mshulman@cravath.com
# LITIGATION
# +1-212-474-1890
# Retired partner
# https://www.cravath.com/people/index.html?f=20&po=5480&s=20
# --------------------------------------------------------------------
# ['Alan C. Stephenson', 'CORPORATE', 'Retired Partner', 'astephenson@cravath.com', '+1-212-474-1400', 'Download vCard', 'EDUCATION', 'J.D., 1970, University of Virginia School of Law', 'A.B., 1967, University of North Carolina at Chapel Hill', 'Phi Beta Kappa, Morehead Scholar']
# Alan C. Stephenson
# astephenson@cravath.com
# CORPORATE
# +1-212-474-1400
# Retired partner
# https://www.cravath.com/people/index.html?f=20&po=5480&s=20
# --------------------------------------------------------------------
# ['Roger D. Turner', 'CORPORATE', 'Retired Partner', 'rturner@cravath.com', '+1-212-474-1668', 'Download vCard', 'EDUCATION', 'J.D., 1976, University of Chicago Law School', 'B.S., 1973, Purdue University', 'with Highest Honors']
# Roger D. Turner
# rturner@cravath.com
# CORPORATE
# +1-212-474-1668
# Retired partner
# https://www.cravath.com/people/index.html?f=20&po=5480&s=20
# --------------------------------------------------------------------
# ['James C. Vardell III', 'CORPORATE', 'Retired Partner', 'jvardell@cravath.com', '+1-212-474-1900', 'Download vCard', 'EDUCATION', 'J.D., 1980, Yale Law School', 'B.A., 1977, Washington and Lee University']
# James C. Vardell III
# jvardell@cravath.com
# CORPORATE
# +1-212-474-1900
# Retired partner
# https://www.cravath.com/people/index.html?f=20&po=5480&s=20
# --------------------------------------------------------------------
# ['Neil P. Westreich', 'CORPORATE', 'Retired Partner', 'nwestreich@cravath.com', '+1-212-474-1518', 'Download vCard', 'EDUCATION', 'M.A., 1978, Cambridge University - Faculty of Law', 'J.D., 1977, Harvard Law School', 'magna cum laude', 'B.A., 1973, Cambridge University - Faculty of Law', 'Honours']
# Neil P. Westreich
# nwestreich@cravath.com
# CORPORATE
# +1-212-474-1518
# Retired partner
# https://www.cravath.com/people/index.html?f=20&po=5480&s=20
# --------------------------------------------------------------------
# ############################################################################
# ['William J. Whelan III', 'CORPORATE', 'Retired Partner', 'wwhelan@cravath.com', '+1-212-474-1644', 'Download vCard', 'EDUCATION', 'J.D., 1983, Fordham University School of Law', 'cum laude', 'B.A., 1980, University of Virginia', 'with Distinction', 'CLERKSHIPS', 'Hon. William H. Timbers, U.S. Court of Appeals for the Second Circuit']
# William J. Whelan III
# wwhelan@cravath.com
# CORPORATE
# +1-212-474-1644
# Retired partner
# https://www.cravath.com/people/index.html?f=40&po=5480&s=20
# --------------------------------------------------------------------
# ['Hon. Rowan D. Wilson', 'LITIGATION', 'Retired Partner', 'Download vCard', 'EDUCATION', 'J.D., 1984, Harvard Law School', 'cum laude', 'A.B., 1981, Harvard College', 'cum laude', 'CLERKSHIPS', 'Hon. James R. Browning, U.S. Court of Appeals for the Ninth Circuit']
# Hon. Rowan D. Wilson
# Null
# LITIGATION
# Null
# Retired partner
# https://www.cravath.com/people/index.html?f=40&po=5480&s=20
# --------------------------------------------------------------------
# ['Peter S. Wilson', 'CORPORATE', 'Retired Partner', 'pwilson@cravath.com', '+1-212-474-1767', 'Download vCard', 'EDUCATION', 'J.D., 1979, Harvard Law School', 'cum laude', 'B.Comm., 1976, McGill University', 'with Great Distinction']
# Peter S. Wilson
# pwilson@cravath.com
# CORPORATE
# +1-212-474-1767
# Retired partner
# https://www.cravath.com/people/index.html?f=40&po=5480&s=20
# --------------------------------------------------------------------
# ************************
# ['Sarah S. B. Kessler', 'OFFICE OF THE GENERAL COUNSEL', 'Associate General Counsel', 'skessler@cravath.com', '+1-212-474-1034', 'Download vCard', 'EDUCATION', 'J.D., 2009, Harvard Law School', 'B.A., 2006, University of Pennsylvania', 'Phi Beta Kappa, summa cum laude', 'CLERKSHIPS', 'Hon. Katherine B. Forrest, U.S.D.C. for the Southern District of New York', 'ADMITTED ONLY IN', 'New York']
# Sarah S. B. Kessler
# skessler@cravath.com
# OFFICE OF THE GENERAL COUNSEL
# +1-212-474-1034
# Associate general counsel
# https://www.cravath.com/people/index.html
# ----------------------------------------------------------------------------------
# ************************
# ['Sophia D. Tawil', 'OFFICE OF THE GENERAL COUNSEL', 'General Counsel', 'stawil@cravath.com', '+1-212-474-1976', 'Download vCard', 'EDUCATION', 'J.D., 2006, University of Pennsylvania Law School', 'B.A., 1999, Barnard College', 'magna cum laude', 'ADMITTED ONLY IN', 'New York']
# Sophia D. Tawil
# stawil@cravath.com
# OFFICE OF THE GENERAL COUNSEL
# +1-212-474-1976
# General counsel
# https://www.cravath.com/people/index.html
# ----------------------------------------------------------------------------------
# ************************

# %%
import selenium
from selenium import webdriver
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
from selenium.webdriver.support.ui import Select
import time
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
import os
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

driverPath = r"C:\Users\Merit\PycharmProjects\chrome\chromedriver_win32 (1)\chromedriver.exe"
driver = webdriver.Chrome(executable_path = driverPath)
driver.get("https://www.cravath.com/people/index.html")
print(driver.title)
print(driver.current_url)
driver.maximize_window()

driver.find_element_by_xpath("(//*[contains(@class, 'icon-Close styles__closeButton--03a22cd7')])").click()
time.sleep(3)
a = driver.find_elements_by_class_name("l-vgap-generic-interior-section")

first=[]
second=[]
third=[]
forth=[]
fifth=[]
sixth=[]
for j in range(0,len(a)):
    try:

        if(a[j].find_element_by_class_name("card-lister-cta__viewAllArrow--875950ce")):

            a[j].find_element_by_class_name("card-lister-cta__viewAllArrow--875950ce").click()
            time.sleep(5)
            while (True):
                part = a[j].find_elements_by_class_name("l-content-container")
                AB = a[j].find_elements_by_class_name("card-lister__box--554421f0")
                for i in range(0, len(AB)):
                    # print(len(AB))
                    # print(AB[1].text)
                    per = AB[i].text.split("\n")
#                     print(per)
                    name = per[0]
                    practice = per[1]
                    index1 = [i for i, elem in enumerate(per) if '@' in elem]
                    email = per[index1[0]] if len(index1) else "Null"
                    index2 = [i for i, elem in enumerate(per) if '+' in elem]
                    tel = per[index2[0]] if len(index2) else "Null"
                    pos = part[0].text.capitalize()


                    first.append(name)
                    second.append(email)
                    third.append(practice)
                    forth.append(tel)
                    fifth.append(pos)
                    sixth.append(driver.current_url)
                    print("--------------------------------------------------------------------")
                try:
                    if (driver.find_element_by_xpath(
                            "(//*[contains(@class, 'styles__arrow--fd23c3f5 icon-caret-thin-right hover-color-dodger-blue')])").is_enabled()):
                        driver.find_element_by_xpath(
                            "(//*[contains(@class, 'styles__arrow--fd23c3f5 icon-caret-thin-right hover-color-dodger-blue')])").click()

                        time.sleep(2)
                        print("############################################################################")
                except:

                    driver.find_element_by_xpath('//a[contains(@href,"https://www.cravath.com/people/index.html")]').click()
                    break
            driver.refresh()


    except:
        part = a[j].find_elements_by_class_name("l-content-container")
        AB = a[j].find_elements_by_class_name("card-lister__box--554421f0")
        for i in range(0, len(AB)):
            # print(len(AB))
            # print(AB[1].text)
            per = AB[i].text.split("\n")
#             print(per)
            name = per[0]
            practice = per[1]
            index1 = [i for i, elem in enumerate(per) if '@' in elem]
            email = per[index1[0]] if len(index1) else "Null"
            index2 = [i for i, elem in enumerate(per) if '+' in elem]
            tel = per[index2[0]] if len(index2) else "Null"
            pos = part[0].text.capitalize()

            first.append(name)
            second.append(email)
            third.append(practice)
            forth.append(tel)
            fifth.append(pos)
            sixth.append(driver.current_url)
            print("----------------------------------------------------------------------------------")
    print("************************")
    a = driver.find_elements_by_class_name("l-vgap-generic-interior-section")
# Out:
# People | Cravath, Swaine & Moore LLP
# https://www.cravath.com/people/index.html
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# ############################################################################
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# ############################################################################
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# ############################################################################
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# ############################################################################
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# ************************
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# ************************
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# ************************
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# ************************
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# ************************
# ----------------------------------------------------------------------------------
# ************************
# ----------------------------------------------------------------------------------
# ************************
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# ############################################################################
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# ############################################################################
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# ############################################################################
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# ############################################################################
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# ############################################################################
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# ############################################################################
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# ############################################################################
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# ############################################################################
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# ############################################################################
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# ############################################################################
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# ############################################################################
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# ############################################################################
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# ############################################################################
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# ############################################################################
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# ############################################################################
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# ############################################################################
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# ############################################################################
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# ************************
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# ************************
# ----------------------------------------------------------------------------------
# ************************
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# ############################################################################
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# ############################################################################
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# ************************
# ----------------------------------------------------------------------------------
# ************************
# ----------------------------------------------------------------------------------
# ************************

# %%
df=pd.DataFrame(list(zip(first,second,third,forth,fifth,sixth)),columns=['Name','Email','Tel','Practice','Position','URL'])

# %%
df
# Out:
#                       Name                   Email  \
# 0         Michael P. Addis      maddis@cravath.com
# 1         Lauren Angelilli  langelilli@cravath.com
# 2         Craig F. Arcella    carcella@cravath.com
# 3        Michael L. Arnold     marnold@cravath.com
# 4          Peter T. Barbur     pbarbur@cravath.com
# ..                     ...                     ...
# 548  William J. Whelan III     wwhelan@cravath.com
# 549   Hon. Rowan D. Wilson                    Null
# 550        Peter S. Wilson     pwilson@cravath.com
# 551    Sarah S. B. Kessler    skessler@cravath.com
# 552        Sophia D. Tawil      stawil@cravath.com
#
#                                Tel         Practice  \
# 0                       LITIGATION  +1-212-474-1956
# 1                              TAX  +1-212-474-1016
# 2                        CORPORATE  +1-212-474-1024
# 3                        CORPORATE  +1-212-474-1664
# 4                       LITIGATION  +1-212-474-1058
# ..                             ...              ...
# 548                      CORPORATE  +1-212-474-1644
# 549                     LITIGATION             Null
# 550                      CORPORATE  +1-212-474-1767
# 551  OFFICE OF THE GENERAL COUNSEL  +1-212-474-1034
# 552  OFFICE OF THE GENERAL COUNSEL  +1-212-474-1976
#
#                       Position  \
# 0                      Partner
# 1                      Partner
# 2                      Partner
# 3                      Partner
# 4                      Partner
# ..                         ...
# 548            Retired partner
# 549            Retired partner
# 550            Retired partner
# 551  Associate general counsel
# 552            General counsel
#
#                                                    URL
# 0    https://www.cravath.com/people/index.html?po=5...
# 1    https://www.cravath.com/people/index.html?po=5...
# 2    https://www.cravath.com/people/index.html?po=5...
# 3    https://www.cravath.com/people/index.html?po=5...
# 4    https://www.cravath.com/people/index.html?po=5...
# ..                                                 ...
# 548  https://www.cravath.com/people/index.html?f=40...
# 549  https://www.cravath.com/people/index.html?f=40...
# 550  https://www.cravath.com/people/index.html?f=40...
# 551          https://www.cravath.com/people/index.html
# 552          https://www.cravath.com/people/index.html
#
# [553 rows x 6 columns]

# %%
pd.set_option('display.max_rows',None)

# %%
writer = pd.ExcelWriter(r'PepoleDetails.xlsx', engine='xlsxwriter')
df.to_excel(writer,index=False)
writer.save()
writer.close()
# Out:
# c:\python39\lib\site-packages\xlsxwriter\workbook.py:338: UserWarning: Calling close() on already closed file.
#   warn("Calling close() on already closed file.")

# %%
import selenium
from selenium import webdriver
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
from selenium.webdriver.support.ui import Select
import time
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
import os
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

# %%
l = [1,2,3,4,5,6,7,8]
for i in l:
    if i%2==0:
        print(i)
# Out:
# 2
# 4
# 6
# 8

# %%
l = [1,2,3,4,5,6,7,8]
q=[i for i in l if i%2==0]
q   

# list comprehension
# Out:
# [2, 4, 6, 8]
