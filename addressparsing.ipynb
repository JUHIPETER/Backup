# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Merit\\Desktop\\Project'

# %%
os.chdir(r"C:\\Users\\Merit\\Desktop\\Project")

# %%
b=pd.read_excel("Juhi_Exercise1.xlsx",sheet_name="Address Parsing")

# %%
df1= pd.DataFrame(b)
df1
address = df1["full_address"]

# %%
address
first=[]
second=[]
third=[]
forth=[]
fifth=[]
mylist = []
# "United Kingdom" in address[0]
for i in range(0,len(address)):
#     if("United Kingdom" in address[i]):
        mylist.append(address[i])
print(mylist)


for p in mylist:
    print(p)
    l =F.split(",")
#       print(l)
#       print(l[2])
    add1 = l[0]
    add2  = l[1]
    country = l[2]
#         print(add1)
#         print(add2)
#         print(country)
    first.append(add1)
    second.append(add2)
    third.append(city)
    forth.append(country)
    fifth.append(Zip)
# Out:
# ['1 Balloon St, Manchester M60 4EP, United Kingdom ', "St Andrew's House, Regent Rd, Edinburgh EH1 3DG, United Kingdom ", "St Andrew's House, Regent Rd, Edinburgh EH1 3DG, United Kingdom ", '2 Holyrood Pl, Dunfermline KY12 7PA, United Kingdom ', "St Andrew's House, Regent Rd, Edinburgh EH1 3DG, United Kingdom ", '2200, Renaissance House, Basing View, Basingstoke RG21 4EQ, United Kingdom ', '99 High St Floor 17, Boston, MA 02110, United States ', 'The Leadenhall Building, 122 Leadenhall St, London EC3V 4AN, United Kingdom ', 'Salhouse Rd, Norwich NR7 9AT, United Kingdom ', 'Killingbeck Dr, Leeds LS14 6UF, United Kingdom ', '527 Madison Ave 4th floor, New York, NY 10022, United States ', '527 Madison Ave 4th floor, New York, NY 10022, United States ', '375 Northridge Rd Suite 400, Atlanta, GA 30350, United States ', '382 Av. de la Châtre, 36000 Châteauroux, France ', '510 Madison Ave #21, New York, NY 10022, United States ', '223 E 83rd St #2, New York, NY 10028, United States ', '320 
# ...

# %%
import pandas as pd
df=pd.DataFrame(list(zip(first,second,third,forth,fifth)),columns=['Address1','Address2','city','Country','zip'])

# %%
pd.set_option('display.max_rows',None)

# %%
df
# Out:
# Empty DataFrame
# Columns: [Address1, Address2, city, Country, zip]
# Index: []

# %%
df1= pd.DataFrame(b)
df1
address = df1["full_address"]
len(address)
first=[]
second=[]
third=[]
forth=[]
fifth=[]
mylist = []
# "United Kingdom" in address[0]
for i in range(0,len(address)):
    if("United Kingdom" in address[i]):
        mylist.append(address[i])
# print(mylist)

for p in mylist:
#     print(p)
    l =p.split(",")
    add1 = l[0]
    city  = l[1]
    postcode = l[2]
#     country = l[3]
    
#     print(add1)
#     print(add2)
#     print(city)
    first.append(add1)
    second.append(city)
    third.append(postcode)
#     forth.append(country)
#     print(country)

# %%
import pandas as pd
df=pd.DataFrame(list(zip(first,second,third)),columns=['Address1','City','Postcode'])

# %%
df
# Out:
#                                       Address1  \
# 0                                 1 Balloon St
# 1                            St Andrew's House
# 2                            St Andrew's House
# 3                                2 Holyrood Pl
# 4                            St Andrew's House
# 5                                         2200
# 6                      The Leadenhall Building
# 7                                  Salhouse Rd
# 8                               Killingbeck Dr
# 9                              1 Creechurch Ln
# 10                                Express Park
# 11                            102 Petty France
# 12                             52-56 Market St
# 13                               425 Oxford St
# 14                            Nationwide House
# 15                             Victoria Square
# 16                                          O2
# 17                               425 Oxford St
# 18                             52-56 Market St
# ...

# %%
len(p)
# Out:
# 46

# %%
df1= pd.DataFrame(b)
df1
address = df1["full_address"]
len(address)
first=[]
second=[]
third=[]
forth=[]
fifth=[]
mylist = []
# "United Kingdom" in address[0]
for i in range(0,len(address)):
    if("United States" in address[i]):
        mylist.append(address[i])
# print(mylist)

for s in mylist:
#     print(s)
    l =s.split(",")
    add1 = l[0]
    city  = l[1]
    postcode = l[2]
    country = l[3]
    from streetaddress import StreetAddressFormatter, StreetAddressParser

    addr_parser = StreetAddressParser()
    addr = addr_parser.parse(add1)
    ad=str(addr['house'])+" "+str(addr['street_full'])
    first.append(ad)
    second.append(addr['other'])
#     print("----------------------")
# print(addr['street_full'])
    
#     print(add1)
#     print(add2)
#     print(city)
#     print(country)
    
    third.append(city)
    forth.append(postcode)
    fifth.append(country)

# %%
df1= pd.DataFrame(b)
df1
address = df1["full_address"]
len(address)
first=[]
second=[]
third=[]
forth=[]
fifth=[]
mylist = []
secondlist = []
thirdlist = []
for i in range(0,len(address)):
    if("United States" in address[i]):
        mylist.append(address[i])
    elif("France" in address[i]):
        secondlist.append(address[i])
    elif("Germany" in address[i]):
        thirdlist.append(address[i])
for s in mylist:
    l =s.split(",")
    add1 = l[0]
    city  = l[1]
    postcode = l[2]
    country = l[3]
    from streetaddress import StreetAddressFormatter, StreetAddressParser
    addr_parser = StreetAddressParser()
    addr = addr_parser.parse(add1)
    ad=str(addr['house'])+" "+str(addr['street_full'])
    first.append(ad)
    second.append(addr['other'])
    third.append(city)
    forth.append(postcode)
    fifth.append(country)

for F in secondlist:
    try:
        l =F.split(",")
        add1 = l[0]
        add2  = l[1]
        ad2 = " "
        res = [re.findall(r'(\d+) (\w+)', add2)]
        city = res[0][0][1]
        pos = res[0][0][0]
        country = l[2]

    except:
        city="na"
        pos="na"
    

    first.append(add1)
    second.append(ad2)
    third.append(city)
    forth.append(pos)
    fifth.append(country)

for G in thirdlist:
        try:
            l =G.split(",")
   
            add1 = l[0]
            add2  = l[1]
            ad2 = " "
            res = [re.findall(r'(\d+) (\w+)', add2)]
            if(len(res)>0):
                city = res[0][0][1]
                pos = res[0][0][0]
 
            country = l[2]
        except:

            city="na"
            pos="na"    
        first.append(add1)
        second.append(ad2)
        third.append(city)
        forth.append(pos)
        fifth.append(country)

# %%
import pandas as pd
df=pd.DataFrame(list(zip(first,second,third,forth,fifth)),columns=['Address1','Address2','City','Postcode','Country'])

# %%
df
# Out:
#                                    Address1    Address2  \
# 0                                99 High St    Floor 17
# 1                           527 Madison Ave   4th floor
# 2                           527 Madison Ave   4th floor
# 3                         375 Northridge Rd        None
# 4                           510 Madison Ave         #21
# 5                             223 E 83rd St          #2
# 6                               320 Post Rd        None
# 7                        9800 Wilshire Blvd        None
# 8                              20 W 22nd St        None
# 9                        7239 S Western Ave        None
# 10                      13201 McCallen Pass        None
# 11                              5326 Van St        None
# 12                       7239 S Western Ave        None
# 13                       7239 S Western Ave        None
# 14                          1 Pontiac Plaza        None
# 15                          6641 W Broad St        None
# ...

# %%
len(s)
# Out:
# 68

# %%
import re
df1= pd.DataFrame(b)
df1
address = df1["full_address"]
len(address)
mylist = []
first=[]
second=[]
third=[]
forth=[]
fifth=[]
# "United Kingdom" in address[0]
for i in range(0,len(address)):
    if("France" in address[i]):
        mylist.append(address[i])
# print(mylist)

for F in mylist:
#     print(F)
    try:
        l =F.split(",")
#       print(l)
#       print(l[2])
        add1 = l[0]
        add2  = l[1]
        ad2 = " "
        res = [re.findall(r'(\d+) (\w+)', add2)]
        city = res[0][0][1]
        pos = res[0][0][0]
        country = l[2]
#         print(city)
#         print(pos)
    except:

        city="na"
        pos="na"
    print(city)
    print(pos)
    print("-----------------")
#         temp = re.compile("([0-9]+)([a-zA-Z]+)")
#         res = temp.match(add2).groups()
#         print(res)
  
#         print(add1)
#         print(add2)
#         print(country)
    first.append(add1)
    second.append(ad2)
    third.append(city)
    forth.append(pos)
    fifth.append(country)
#         fifth.append(Zip)
# Out:
# Châteauroux
# 36000
# -----------------
# La
# 59110
# -----------------
# Lestrem
# 62136
# -----------------
# na
# na
# -----------------
# Écully
# 69130
# -----------------
# Boulogne
# 62200
# -----------------
# Tassin
# 69160
# -----------------
# Rueil
# 92563
# -----------------
# Écully
# 69130
# -----------------
# Écully
# 69130
# -----------------
# Toulouse
# 31300
# -----------------
# Toulouse
# 31300
# -----------------
# Toulouse
# 31300
# -----------------
# Le
# 92350
# -----------------
# Paris
# 75014
# -----------------
# Paris
# 75014
# -----------------
# Paris
# 75014
# -----------------
# Paris
# 75014
# -----------------
# Paris
# 75014
# -----------------
# Boulogne
# 92100
# -----------------
# Boulogne
# 92100
# -----------------
# Paris
# 75014
# -----------------
# Boulogne
# 92100
# -----------------
# Paris
# 75014
# -----------------
# Paris
# 75014
# -----------------
# Paris
# 75014
# -----------------
# na
# na
# -----------------
# Paris
# ...

# %%
import re
temp ="75014 Paris"
res = [re.findall(r'(\d+) (\w+)', temp)]
print(res)
res[0][0][0]
# Out:
# [[('75014', 'Paris')]]
# '75014'

# %%
import pandas as pd
df=pd.DataFrame(list(zip(first,second,third,forth,fifth)),columns=['Address1','Address2','city','pin','Country'])

# %%
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#                                  Address1 Address2         city    pin  \
# 0                    382 Av. de la Châtre           Châteauroux  36000
# 1                101 Av. de la République                    La  59110
# 2                    Rue de la Haute Loge               Lestrem  62136
# 3                        102 Petty France                    na     na
# 4                 4 M Chem. du Petit Bois                Écully  69130
# 5                60 Rue du Camp de Droite              Boulogne  62200
# 6                         74 Rte de Paris                Tassin  69160
# 7    8-10 Rue Henri Sainte-Claire Deville                 Rueil  92563
# 8                 4 M Chem. du Petit Bois                Écully  69130
# 9                 4 M Chem. du Petit Bois                Écully  69130
# 10                                  Aneto              Toulouse  31300
# 11                     316 Rte de Bayonne              Toulouse  31300
# ...

# %%
len(F)
# Out:
# 40

# %%
df1= pd.DataFrame(b)
df1
address = df1["full_address"]
len(address)
first=[]
second=[]
third=[]
forth=[]
fifth=[]
mylist = []
# "United Kingdom" in address[0]
for i in range(0,len(address)):
    if("Germany" in address[i]):
        mylist.append(address[i])

for G in mylist:
        try:
            l =G.split(",")
   
            add1 = l[0]
            add2  = l[1]
            ad2 = " "
            res = [re.findall(r'(\d+) (\w+)', add2)]
            if(len(res)>0):
                city = res[0][0][1]
                pos = res[0][0][0]
 
            country = l[2]
        except:

            city="na"
            pos="na"
            

        first.append(add1)
        second.append(ad2)
        third.append(city)
        forth.append(pos)
        fifth.append(country)
# Out:
# Leipzig
# 04249
# Nürnberg
# 90409
# Leipzig
# 04249
# Flörsheim
# 67592
# Frankfurt
# 60437
# Wolfsburg
# 38440
# Wolfsburg
# 38440
# Braunschweig
# 38108
# Wolfsburg
# 38440
# na
# na
# Wolfsburg
# 38440
# Wolfsburg
# 38440
# Wolfsburg
# 38440
# Wolfsburg
# 38440
# Hamburg
# 22335
# Hamburg
# 22335
# Nürnberg
# 90402
# Nürnberg
# 90402
# Nürnberg
# 90402
# Herzogenaurach
# 91074
# Kassel
# 34117
# Augsburg
# 86154
# Nürnberg
# 90402
# na
# na
# na
# na
# na
# na
# Ismaning
# 85737
# Köln
# 50829
# Düsseldorf
# 40212
# Bonn
# 53111
# Stuttgart
# 70372
# Stuttgart
# 70372
# Kassel
# 34127
# Berlin
# 12277
# Stuttgart
# 70372
# Düsseldorf
# 40212
# Kassel
# 34127
# Stuttgart
# 70372
# Metzingen
# 72555
# Frankfurt
# 60313
# Metzingen
# 72555
# Berlin
# 10719
# Metzingen
# 72555
# Metzingen
# 72555
# Metzingen
# 72555
# Hamburg
# 20354
# Hamburg
# 20354
# Nürnberg
# 90411
# München
# 80807
# Montabaur
# 56410
# Menden
# 58708
# Frankfurt
# 60314
# Berlin
# 10245
# Berlin
# 10245
# ...

# %%
import pandas as pd
df=pd.DataFrame(list(zip(first,second,third,forth,fifth)),columns=['Address1','Address2','city','pin','Country'])

# %%
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#                                   Address1 Address2            city    pin  \
# 0                       Dieskaustraße 126،                  Leipzig  04249
# 1                            Schleifweg 53                 Nürnberg  90409
# 2                       Dieskaustraße 126،                  Leipzig  04249
# 3                              Am Goldberg                Flörsheim  67592
# 4                          Züricher Str. 7                Frankfurt  60437
# 5                          Berliner Ring 2                Wolfsburg  38440
# 6                          Berliner Ring 2                Wolfsburg  38440
# 7                   Hermann-Blenk-Straße 8             Braunschweig  38108
# 8                          Berliner Ring 2                Wolfsburg  38440
# 9                                       Dr                       na     na
# 10                         Berliner Ring 2                Wolfsburg  38440
# ...

# %%
import pycountry
len(pycountry.countries)
# Out:
# 249

# %%
len(G)
# Out:
# 56

# %%
print(l[0])
# Out:
# Felix-Wankel-Straße 8

# %%
Neuer Wall 73-75, 20354 Hamburg, Germany

# %%
import re
temp ="Neuer Wall 73-75, 20354 Hamburg, Germany"
res = [re.split("\s",temp,1)]
print(res)
res[0]
# res[0][1]
# res[0][2]
# res[0][3]
# Out:
# [['Neuer', 'Wall 73-75, 20354 Hamburg, Germany']]
# ['Neuer', 'Wall 73-75, 20354 Hamburg, Germany']

# %%
l =G.split(",")
print(l)
# Out:
# ['Felix-Wankel-Straße 8', ' 60314 Frankfurt am Main', ' Germany ']

# %%
pip install street-address
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Using legacy 'setup.py install' for street-address, since package 'wheel' is not installed.
# ...
#     Running setup.py install for street-address: started
#     Running setup.py install for street-address: finished with status 'done'
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pycountry
# for country in pycountry.countries:
# if country.name in i:
from streetaddress import StreetAddressFormatter, StreetAddressParser

addr_parser = StreetAddressParser()
addr = addr_parser.parse("99 High St Floor 17 ") 
addr['other']
print(addr['house'])

print(addr['street_full'])
#     #Pennsylvania Ave
# print(addr['street_name']) #Pennsylvania 
# # print(addr['street_type']) #Ave
# print(.name)
# Out:
# 99
# High St

# %%
pip install pycountry
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Using legacy 'setup.py install' for pycountry, since package 'wheel' is not installed.
# ...
#     Running setup.py install for pycountry: started
#     Running setup.py install for pycountry: finished with status 'done'
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
for country in pycountry.countries:
if country.name in i:

# %%
import pycountry

# %%
 import pycountry
>>> len(pycountry.countries)

# %%
for country in p

# %%
import pycountry
country = pycountry.countries.get(alpha_2=region_code_for_number(pn))
>>> print(country.name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15104/2861815821.py in <module>
#       1 import pycountry
# ----> 2 country = pycountry.countries.get(alpha_2=region_code_for_number(pn))
#       3 print(country.name)
#
# NameError: name 'region_code_for_number' is not defined

# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Merit\\Desktop\\Project'

# %%
os.chdir(r"C:\\Users\\Merit\\Desktop\\Project")

# %%
b=pd.read_excel("Juhi_Exercise1.xlsx",sheet_name="Address Parsing")

# %%
import pandas as pd
import pycountry

df1= pd.DataFrame(b)
df1
address = df1["full_address"]
address
for i in address:
    for country in pycountry.countries:
        if country.name in i:
            print(country.name)
# Out:
# United Kingdom
# United Kingdom
# United Kingdom
# United Kingdom
# United Kingdom
# United Kingdom
# United States
# United Kingdom
# United Kingdom
# United Kingdom
# United States
# United States
# United States
# France
# United States
# United States
# United States
# United States
# United Kingdom
# United States
# United States
# United States
# United States
# United States
# United Kingdom
# France
# France
# United States
# France
# United Kingdom
# France
# United States
# Germany
# United States
# United States
# United Kingdom
# United Kingdom
# France
# United States
# Germany
# Germany
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# France
# United States
# United States
# United States
# United States
# United States
# United States
# United Kingdom
# United States
# United States
# United States
# United States
# United States
# United States
# ...

# %%
import pycountry
for c in pycountry.countries:
    print(c.name)

# %%
import pycountry
text = "United States (New York), United Kingdom (London)"

for country in pycountry.countries:
    if country.name in text:
        print(country.name)
# Out:
# United Kingdom
# United States

# %%
pip install locationtagger
# Out:
# ...
#   Using cached locationtagger-0.0.1-py3-none-any.whl (1.6 MB)
# ...
#   Using cached newspaper3k-0.2.8-py3-none-any.whl (211 kB)
# ...
#   Using cached spacy-3.2.0-cp39-cp39-win_amd64.whl (11.7 MB)
# ...
#   Using cached tinysegmenter-0.3.tar.gz (16 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached lxml-4.6.4-cp39-cp39-win_amd64.whl (3.5 MB)
# ...
#   Using cached cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# ...
#   Using cached tldextract-3.1.2-py2.py3-none-any.whl (87 kB)
# ...
#   Using cached feedfinder2-0.0.4.tar.gz (3.3 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached PyYAML-6.0-cp39-cp39-win_amd64.whl (151 kB)
# ...
#   Using cached feedparser-6.0.8-py3-none-any.whl (81 kB)
# ...
#   Using cached jieba3k-0.35.1.zip (7.4 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...

# %%
import nltk
import spacy

# essential entity models downloads
nltk.downloader.download('maxent_ne_chunker')
nltk.downloader.download('words')
nltk.downloader.download('treebank')
nltk.downloader.download('maxent_treebank_pos_tagger')
nltk.downloader.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\Merit\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Merit\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# [nltk_data] Downloading package treebank to
# [nltk_data]     C:\Users\Merit\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\treebank.zip.
# [nltk_data] Downloading package maxent_treebank_pos_tagger to
# [nltk_data]     C:\Users\Merit\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\maxent_treebank_pos_tagger.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Merit\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Merit\AppData\Roaming\nltk_data...
# ...

# %%
import locationtagger
import pandas as pd
df1= pd.DataFrame(b)
df1
address = df1["full_address"]
import re
# initializing sample text
# sample_text = "Hugo-Boss-Platz 1, 72555 Metzingen, Germany "
for i in address:
    
#      place_entity = locationtagger.find_locations(text = i)

#     # getting all countries
#     print("The countries in text : ")
#     print(place_entity.countries)


#     # getting all states
#     print("The states in text : ")
#     print(place_entity.regions)

#     # getting all cities
#     print("The cities in text : ")
#     print(place_entity.cities)
#     print("-----------------------")
# s = "31 Rue Cambon, 75001 Paris, France "
    lst=re.split(r'(?<=\d)(?:-\d+)?\s+', i)
    print(lst[0]+" "+lst[1])
    import locationtagger
    place_entity = locationtagger.find_locations(text = i)
    print(place_entity.countries[0])
    print("_____________")
# extracting entities.
# Out:
# 1 Balloon St, Manchester M60
# United Kingdom
# _____________
# St Andrew's House, Regent Rd, Edinburgh EH1 3DG, United Kingdom
# United Kingdom
# _____________
# St Andrew's House, Regent Rd, Edinburgh EH1 3DG, United Kingdom
# United Kingdom
# _____________
# 2 Holyrood Pl, Dunfermline KY12
# United Kingdom
# _____________
# St Andrew's House, Regent Rd, Edinburgh EH1 3DG, United Kingdom
# United Kingdom
# _____________
# 2200, Renaissance House, Basing View, Basingstoke RG21 4EQ, United Kingdom
# United Kingdom
# _____________
# 99 High St Floor 17, Boston, MA 02110, United States
# United States
# _____________
# The Leadenhall Building, 122 Leadenhall St, London EC3V 4AN, United Kingdom
# United Kingdom
# _____________
# Salhouse Rd, Norwich NR7 9AT, United Kingdom
# United Kingdom
# _____________
# Killingbeck Dr, Leeds LS14 6UF, United Kingdom
# United Kingdom
# _____________
# 527 Madison Ave 4th floor, New York, NY 10022, United States
# United States
# _____________
# ...

# %%
import re
# regex = re.compile(r'/^[0-9]* (.*), (.*) [a-zA-Z]{2} [0-9]{5}(-[0-9]{4})?$/')
add="1 Balloon St, Manchester M60 4EP, United Kingdom"
z=re.findall(r'/^[0-9]* (.*), (.*) [a-zA-Z]{2} [0-9]{5}(-[0-9]{4})?$/',add)
z
# Out:
# []

# %%
import re
s = "99 High St Floor 17"
lst=re.split(r'(?<=\d)(?:-\d+)?\s+', s)
print(lst)
# import locationtagger
# place_entity = locationtagger.find_locations(text = s)
# print(place_entity.countries[0])
# Out:
# ['99', 'High St Floor 17']
